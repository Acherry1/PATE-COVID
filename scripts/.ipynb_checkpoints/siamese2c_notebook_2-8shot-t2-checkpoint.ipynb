# %%
# -*- coding: utf-8 -*-
import utils as utils

import tensorflow as tf
from tensorflow.keras.layers import Dense, Input, Flatten, Lambda
from tensorflow.keras.models import Model
from tensorflow.keras.optimizers import Adam
from sklearn.metrics import accuracy_score, precision_score, recall_score, roc_auc_score, f1_score

from sklearn.metrics import confusion_matrix
from sklearn.metrics import ConfusionMatrixDisplay

import numpy as np
import os

from tensorflow.keras.callbacks import EarlyStopping, ModelCheckpoint, ReduceLROnPlateau
import matplotlib.pyplot as plt
import logging

logger = tf.get_logger()
logger.setLevel(logging.ERROR)

# %%
all_teachers=2
teacher_id = 2
epochs = 175
shot = 8
SIAMESE_MODEL_NAME = '..\scripts\models_h5\siamese_network2c-t{}_{}notebook.h5'.format(teacher_id,shot)
EMBEDDING_MODEL_NAME = 'embedding_network2w_0801.h5'
if os.path.exists(SIAMESE_MODEL_NAME):
    os.remove(SIAMESE_MODEL_NAME)

# %%
base_dir = r"..\scripts\dataset"
dataset_path = os.path.join( r"..\scripts\auto_datasets", r"auto_t{}_{}\t{}-{}".format(all_teachers,shot,teacher_id, shot))
result_file_path = os.path.join(base_dir, r"true_result_xlsx")
pre_results_path = os.path.join(base_dir, r"teacher_results_xlsx","result_{}_{}".format(all_teachers,shot))
train_image_list, train_y_list = utils.load_images(dataset_path, 'train', (100, 100))
print("The train set contains", len(train_image_list))
# Out:
# Found 18 images belonging to 2 classes.
# The train set contains 18

# %%
test_path = r"../scripts/dataset/pretrain_2c_0727/"
valid_image_list, valid_y_list = utils.load_images(test_path, 'valid', (100, 100))
print("The valid set contains", len(valid_image_list))
# Out:
# Found 1200 images belonging to 2 classes.
# The valid set contains 1200

# %%
test_image_list, test_y_list = utils.load_images(test_path, 'test', (100, 100))
print("The test set contains", len(test_image_list))
# Out:
# Found 1200 images belonging to 2 classes.
# The test set contains 1200

# %%
# make train pairs
pairs_train, labels_train, source_labels_train, true_labels_train = utils.make_pairs(train_image_list, train_y_list)

# make validation pairs
pairs_val, labels_val, source_labels_val, true_labels_val = utils.make_pairs(valid_image_list, valid_y_list)

# make validation pairs
pairs_test, labels_test, source_labels_test, true_labels_test = utils.make_pairs(test_image_list, test_y_list)
# Out:
# num_classes: 2
# num_classes: 2
# num_classes: 2

# %%
import pandas as pd

# %%
x_train_1 = pairs_train[:, 0]  # x1(如何给标签带上)
x_train_2 = pairs_train[:, 1]  # x2
print("number of pairs for train", np.shape(x_train_1)[0])

x_val_1 = pairs_val[:, 0]
x_val_2 = pairs_val[:, 1]
print("number of pairs for validation", np.shape(x_val_1)[0])

x_test_1 = pairs_test[:, 0]
x_test_2 = pairs_test[:, 1]
# print(x_test_1)
print("number of pairs for test", np.shape(x_test_1)[0])
# Out:
# number of pairs for train 36
# number of pairs for validation 2400
# number of pairs for test 2400

# %%
if not os.path.exists(result_file_path):
    os.makedirs(result_file_path)
result_xlsx=os.path.join(result_file_path,"true_labels.xlsx")
if not os.path.exists(result_xlsx):
    test_1_image_list = x_test_1.tolist()
    df = pd.DataFrame({"image": test_1_image_list, "true_label": true_labels_test})
    df.to_excel(result_xlsx, index=False)
    df = pd.read_excel(result_xlsx)
    df.drop_duplicates(inplace=True)
    df.to_excel(result_xlsx, index=False)

# %%
tf.compat.v1.reset_default_graph()

input_1 = Input((100, 100, 3))
input_2 = Input((100, 100, 3))

embedding_network = tf.keras.models.load_model(EMBEDDING_MODEL_NAME)
embedding_network.trainable = False

model = tf.keras.Sequential()
for layer in embedding_network.layers:
    model.add(layer)

model.add(Flatten(name='flat'))
model.add(Dense(5120, name='den', activation='sigmoid', kernel_regularizer='l2'))

output_1 = model(input_1)
output_2 = model(input_2)

merge_layer = Lambda(utils.manhattan_distance)([output_1, output_2])
output_layer = Dense(1, activation="sigmoid")(merge_layer)
siamese = Model(inputs=[input_1, input_2], outputs=output_layer)
siamese.summary()
# Out:
# Model: "model"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ==================================================================================================
#  input_1 (InputLayer)           [(None, 100, 100, 3  0           []
#                                 )]
#
#  input_2 (InputLayer)           [(None, 100, 100, 3  0           []
#                                 )]
#
#  sequential (Sequential)        (None, 5120)         14739266    ['input_1[0][0]',
#                                                                   'input_2[0][0]']
#
#  lambda (Lambda)                (None, 1)            0           ['sequential[0][0]',
#                                                                   'sequential[1][0]']
#
#  dense (Dense)                  (None, 1)            2           ['lambda[0][0]']
#
# ==================================================================================================
# Total params: 14,739,268
# Trainable params: 15,362
# Non-trainable params: 14,723,906
# __________________________________________________________________________________________________

# %%
reduce_lr = ReduceLROnPlateau(monitor='val_loss', factor=0.2, patience=5, min_lr=0.00001)

early_stopping = EarlyStopping(monitor='val_loss', patience=10, verbose=1, min_delta=0.0001)

checkpointer = ModelCheckpoint(filepath=SIAMESE_MODEL_NAME, verbose=1,
                               save_best_only=True)

# %%
optimizer = Adam(learning_rate=0.0001)
siamese.compile(loss=utils.loss(1), optimizer=optimizer, metrics=["accuracy"])
# siamese.compile(loss='sparse_categorical_crossentropy', optimizer=optimizer, metrics=["accuracy"])

siamese.summary()
history = siamese.fit([x_train_1, x_train_2],
                      labels_train,
                      validation_data=([x_val_1, x_val_2], labels_val),
                      batch_size=1,
                      epochs=epochs,  # 175 for contrastive 100 for cross ent
                      callbacks=[checkpointer, early_stopping, reduce_lr]
                      )
# print()
# Plot the accuracy
utils.plt_metric(history=history.history, metric="accuracy", title="Model accuracy")

# Plot the constrastive loss
utils.plt_metric(history=history.history, metric="loss", title="Constrastive Loss")
# Out:
# Model: "model"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ==================================================================================================
#  input_1 (InputLayer)           [(None, 100, 100, 3  0           []
#                                 )]
#
#  input_2 (InputLayer)           [(None, 100, 100, 3  0           []
#                                 )]
#
#  sequential (Sequential)        (None, 5120)         14739266    ['input_1[0][0]',
#                                                                   'input_2[0][0]']
#
#  lambda (Lambda)                (None, 1)            0           ['sequential[0][0]',
#                                                                   'sequential[1][0]']
#
#  dense (Dense)                  (None, 1)            2           ['lambda[0][0]']
#
# ==================================================================================================
# Total params: 14,739,268
# Trainable params: 15,362
# Non-trainable params: 14,723,906
# __________________________________________________________________________________________________
# Epoch 1/175
# 36/36 [==============================] - ETA: 0s - loss: 0.1816 - accuracy: 0.6389
# Epoch 00001: val_loss improved from inf to 0.28897, saving model to ..\scripts\models_h5\siamese_network2c-t2_9notebook.h5
# 36/36 [==============================] - 262s 7s/step - loss: 0.1816 - accuracy: 0.6389 - val_loss: 0.2890 - val_accuracy: 0.5167 - lr: 1.0000e-04
# Epoch 2/175
# 36/36 [==============================] - ETA: 0s - loss: 0.1697 - accuracy: 0.7500
# Epoch 00002: val_loss improved from 0.28897 to 0.27280, saving model to ..\scripts\models_h5\siamese_network2c-t2_9notebook.h5
# 36/36 [==============================] - 241s 7s/step - loss: 0.1697 - accuracy: 0.7500 - val_loss: 0.2728 - val_accuracy: 0.5329 - lr: 1.0000e-04
# Epoch 3/175
# 36/36 [==============================] - ETA: 0s - loss: 0.1602 - accuracy: 0.7778
# Epoch 00003: val_loss improved from 0.27280 to 0.25558, saving model to ..\scripts\models_h5\siamese_network2c-t2_9notebook.h5
# 36/36 [==============================] - 248s 7s/step - loss: 0.1602 - accuracy: 0.7778 - val_loss: 0.2556 - val_accuracy: 0.5533 - lr: 1.0000e-04
# Epoch 4/175
# 36/36 [==============================] - ETA: 0s - loss: 0.1522 - accuracy: 0.8056
# Epoch 00004: val_loss improved from 0.25558 to 0.24059, saving model to ..\scripts\models_h5\siamese_network2c-t2_9notebook.h5
# 36/36 [==============================] - 264s 8s/step - loss: 0.1522 - accuracy: 0.8056 - val_loss: 0.2406 - val_accuracy: 0.5729 - lr: 1.0000e-04
# Epoch 5/175
# 36/36 [==============================] - ETA: 0s - loss: 0.1456 - accuracy: 0.8333
# Epoch 00005: val_loss improved from 0.24059 to 0.22640, saving model to ..\scripts\models_h5\siamese_network2c-t2_9notebook.h5
# 36/36 [==============================] - 264s 8s/step - loss: 0.1456 - accuracy: 0.8333 - val_loss: 0.2264 - val_accuracy: 0.5900 - lr: 1.0000e-04
# Epoch 6/175
# 36/36 [==============================] - ETA: 0s - loss: 0.1406 - accuracy: 0.8333
# Epoch 00006: val_loss improved from 0.22640 to 0.21276, saving model to ..\scripts\models_h5\siamese_network2c-t2_9notebook.h5
# 36/36 [==============================] - 264s 8s/step - loss: 0.1406 - accuracy: 0.8333 - val_loss: 0.2128 - val_accuracy: 0.6087 - lr: 1.0000e-04
# Epoch 7/175
# 36/36 [==============================] - ETA: 0s - loss: 0.1377 - accuracy: 0.8333
# Epoch 00007: val_loss improved from 0.21276 to 0.20585, saving model to ..\scripts\models_h5\siamese_network2c-t2_9notebook.h5
# 36/36 [==============================] - 263s 8s/step - loss: 0.1377 - accuracy: 0.8333 - val_loss: 0.2059 - val_accuracy: 0.6237 - lr: 1.0000e-04
# Epoch 8/175
# 36/36 [==============================] - ETA: 0s - loss: 0.1360 - accuracy: 0.8611
# Epoch 00008: val_loss did not improve from 0.20585
# 36/36 [==============================] - 265s 8s/step - loss: 0.1360 - accuracy: 0.8611 - val_loss: 0.2062 - val_accuracy: 0.6267 - lr: 1.0000e-04
# Epoch 9/175
# 36/36 [==============================] - ETA: 0s - loss: 0.1346 - accuracy: 0.8611
# Epoch 00009: val_loss improved from 0.20585 to 0.20358, saving model to ..\scripts\models_h5\siamese_network2c-t2_9notebook.h5
# 36/36 [==============================] - 264s 8s/step - loss: 0.1346 - accuracy: 0.8611 - val_loss: 0.2036 - val_accuracy: 0.6329 - lr: 1.0000e-04
# Epoch 10/175
# 36/36 [==============================] - ETA: 0s - loss: 0.1334 - accuracy: 0.8611
# Epoch 00010: val_loss did not improve from 0.20358
# 36/36 [==============================] - 264s 8s/step - loss: 0.1334 - accuracy: 0.8611 - val_loss: 0.2053 - val_accuracy: 0.6346 - lr: 1.0000e-04
# Epoch 11/175
# 36/36 [==============================] - ETA: 0s - loss: 0.1323 - accuracy: 0.8611
# Epoch 00011: val_loss improved from 0.20358 to 0.20180, saving model to ..\scripts\models_h5\siamese_network2c-t2_9notebook.h5
# 36/36 [==============================] - 264s 8s/step - loss: 0.1323 - accuracy: 0.8611 - val_loss: 0.2018 - val_accuracy: 0.6438 - lr: 1.0000e-04
# Epoch 12/175
# 36/36 [==============================] - ETA: 0s - loss: 0.1314 - accuracy: 0.8611
# Epoch 00012: val_loss improved from 0.20180 to 0.20033, saving model to ..\scripts\models_h5\siamese_network2c-t2_9notebook.h5
# 36/36 [==============================] - 265s 8s/step - loss: 0.1314 - accuracy: 0.8611 - val_loss: 0.2003 - val_accuracy: 0.6488 - lr: 1.0000e-04
# Epoch 13/175
# 36/36 [==============================] - ETA: 0s - loss: 0.1305 - accuracy: 0.8611
# Epoch 00013: val_loss improved from 0.20033 to 0.20029, saving model to ..\scripts\models_h5\siamese_network2c-t2_9notebook.h5
# 36/36 [==============================] - 208s 6s/step - loss: 0.1305 - accuracy: 0.8611 - val_loss: 0.2003 - val_accuracy: 0.6521 - lr: 1.0000e-04
# Epoch 14/175
# 36/36 [==============================] - ETA: 0s - loss: 0.1300 - accuracy: 0.8611
# Epoch 00014: val_loss did not improve from 0.20029
# 36/36 [==============================] - 207s 6s/step - loss: 0.1300 - accuracy: 0.8611 - val_loss: 0.2037 - val_accuracy: 0.6517 - lr: 1.0000e-04
# Epoch 15/175
# 36/36 [==============================] - ETA: 0s - loss: 0.1294 - accuracy: 0.8611
# Epoch 00015: val_loss did not improve from 0.20029
# 36/36 [==============================] - 208s 6s/step - loss: 0.1294 - accuracy: 0.8611 - val_loss: 0.2008 - val_accuracy: 0.6575 - lr: 1.0000e-04
# Epoch 16/175
# 36/36 [==============================] - ETA: 0s - loss: 0.1287 - accuracy: 0.8611
# Epoch 00016: val_loss improved from 0.20029 to 0.20000, saving model to ..\scripts\models_h5\siamese_network2c-t2_9notebook.h5
# 36/36 [==============================] - 208s 6s/step - loss: 0.1287 - accuracy: 0.8611 - val_loss: 0.2000 - val_accuracy: 0.6625 - lr: 1.0000e-04
# Epoch 17/175
# 36/36 [==============================] - ETA: 0s - loss: 0.1282 - accuracy: 0.8611
# Epoch 00017: val_loss improved from 0.20000 to 0.19850, saving model to ..\scripts\models_h5\siamese_network2c-t2_9notebook.h5
# 36/36 [==============================] - 208s 6s/step - loss: 0.1282 - accuracy: 0.8611 - val_loss: 0.1985 - val_accuracy: 0.6683 - lr: 1.0000e-04
# Epoch 18/175
# 36/36 [==============================] - ETA: 0s - loss: 0.1277 - accuracy: 0.8611
# Epoch 00018: val_loss did not improve from 0.19850
# 36/36 [==============================] - 208s 6s/step - loss: 0.1277 - accuracy: 0.8611 - val_loss: 0.2002 - val_accuracy: 0.6683 - lr: 1.0000e-04
# Epoch 19/175
# 36/36 [==============================] - ETA: 0s - loss: 0.1274 - accuracy: 0.8611
# Epoch 00019: val_loss improved from 0.19850 to 0.19679, saving model to ..\scripts\models_h5\siamese_network2c-t2_9notebook.h5
# 36/36 [==============================] - 209s 6s/step - loss: 0.1274 - accuracy: 0.8611 - val_loss: 0.1968 - val_accuracy: 0.6775 - lr: 1.0000e-04
# Epoch 20/175
# 36/36 [==============================] - ETA: 0s - loss: 0.1270 - accuracy: 0.8611
# Epoch 00020: val_loss improved from 0.19679 to 0.19673, saving model to ..\scripts\models_h5\siamese_network2c-t2_9notebook.h5
# 36/36 [==============================] - 207s 6s/step - loss: 0.1270 - accuracy: 0.8611 - val_loss: 0.1967 - val_accuracy: 0.6829 - lr: 1.0000e-04
# Epoch 21/175
# 36/36 [==============================] - ETA: 0s - loss: 0.1265 - accuracy: 0.8889
# Epoch 00021: val_loss did not improve from 0.19673
# 36/36 [==============================] - 208s 6s/step - loss: 0.1265 - accuracy: 0.8889 - val_loss: 0.1977 - val_accuracy: 0.6837 - lr: 1.0000e-04
# Epoch 22/175
# 36/36 [==============================] - ETA: 0s - loss: 0.1261 - accuracy: 0.8889
# Epoch 00022: val_loss did not improve from 0.19673
# 36/36 [==============================] - 208s 6s/step - loss: 0.1261 - accuracy: 0.8889 - val_loss: 0.1976 - val_accuracy: 0.6825 - lr: 1.0000e-04
# Epoch 23/175
# 36/36 [==============================] - ETA: 0s - loss: 0.1258 - accuracy: 0.8889
# Epoch 00023: val_loss improved from 0.19673 to 0.19652, saving model to ..\scripts\models_h5\siamese_network2c-t2_9notebook.h5
# 36/36 [==============================] - 207s 6s/step - loss: 0.1258 - accuracy: 0.8889 - val_loss: 0.1965 - val_accuracy: 0.6871 - lr: 1.0000e-04
# Epoch 24/175
# 36/36 [==============================] - ETA: 0s - loss: 0.1254 - accuracy: 0.8889
# Epoch 00024: val_loss did not improve from 0.19652
# 36/36 [==============================] - 207s 6s/step - loss: 0.1254 - accuracy: 0.8889 - val_loss: 0.1970 - val_accuracy: 0.6888 - lr: 1.0000e-04
# Epoch 25/175
# 36/36 [==============================] - ETA: 0s - loss: 0.1252 - accuracy: 0.8889
# Epoch 00025: val_loss improved from 0.19652 to 0.19592, saving model to ..\scripts\models_h5\siamese_network2c-t2_9notebook.h5
# 36/36 [==============================] - 209s 6s/step - loss: 0.1252 - accuracy: 0.8889 - val_loss: 0.1959 - val_accuracy: 0.6929 - lr: 1.0000e-04
# Epoch 26/175
# 36/36 [==============================] - ETA: 0s - loss: 0.1248 - accuracy: 0.8889
# Epoch 00026: val_loss did not improve from 0.19592
# 36/36 [==============================] - 208s 6s/step - loss: 0.1248 - accuracy: 0.8889 - val_loss: 0.1969 - val_accuracy: 0.6933 - lr: 1.0000e-04
# Epoch 27/175
# 36/36 [==============================] - ETA: 0s - loss: 0.1245 - accuracy: 0.8889
# Epoch 00027: val_loss improved from 0.19592 to 0.19430, saving model to ..\scripts\models_h5\siamese_network2c-t2_9notebook.h5
# 36/36 [==============================] - 208s 6s/step - loss: 0.1245 - accuracy: 0.8889 - val_loss: 0.1943 - val_accuracy: 0.7021 - lr: 1.0000e-04
# Epoch 28/175
# 36/36 [==============================] - ETA: 0s - loss: 0.1241 - accuracy: 0.8889
# Epoch 00028: val_loss did not improve from 0.19430
# 36/36 [==============================] - 208s 6s/step - loss: 0.1241 - accuracy: 0.8889 - val_loss: 0.1951 - val_accuracy: 0.7029 - lr: 1.0000e-04
# Epoch 29/175
# 36/36 [==============================] - ETA: 0s - loss: 0.1239 - accuracy: 0.8889
# Epoch 00029: val_loss did not improve from 0.19430
# 36/36 [==============================] - 211s 6s/step - loss: 0.1239 - accuracy: 0.8889 - val_loss: 0.1950 - val_accuracy: 0.7033 - lr: 1.0000e-04
# Epoch 30/175
# 36/36 [==============================] - ETA: 0s - loss: 0.1237 - accuracy: 0.8889
# Epoch 00030: val_loss did not improve from 0.19430
# 36/36 [==============================] - 208s 6s/step - loss: 0.1237 - accuracy: 0.8889 - val_loss: 0.1954 - val_accuracy: 0.7079 - lr: 1.0000e-04
# Epoch 31/175
# 36/36 [==============================] - ETA: 0s - loss: 0.1232 - accuracy: 0.8889
# Epoch 00031: val_loss did not improve from 0.19430
# 36/36 [==============================] - 207s 6s/step - loss: 0.1232 - accuracy: 0.8889 - val_loss: 0.1964 - val_accuracy: 0.7079 - lr: 1.0000e-04
# Epoch 32/175
# 36/36 [==============================] - ETA: 0s - loss: 0.1230 - accuracy: 0.8889
# Epoch 00032: val_loss did not improve from 0.19430
# 36/36 [==============================] - 208s 6s/step - loss: 0.1230 - accuracy: 0.8889 - val_loss: 0.1955 - val_accuracy: 0.7117 - lr: 1.0000e-04
# Epoch 33/175
# 36/36 [==============================] - ETA: 0s - loss: 0.1227 - accuracy: 0.8889 ETA: 0s - loss: 0.1254 - accuracy:
# Epoch 00033: val_loss did not improve from 0.19430
# 36/36 [==============================] - 208s 6s/step - loss: 0.1227 - accuracy: 0.8889 - val_loss: 0.1952 - val_accuracy: 0.7129 - lr: 2.0000e-05
# Epoch 34/175
# 36/36 [==============================] - ETA: 0s - loss: 0.1226 - accuracy: 0.8889
# Epoch 00034: val_loss improved from 0.19430 to 0.19379, saving model to ..\scripts\models_h5\siamese_network2c-t2_9notebook.h5
# 36/36 [==============================] - 208s 6s/step - loss: 0.1226 - accuracy: 0.8889 - val_loss: 0.1938 - val_accuracy: 0.7142 - lr: 2.0000e-05
# Epoch 35/175
# 36/36 [==============================] - ETA: 0s - loss: 0.1226 - accuracy: 0.8889
# Epoch 00035: val_loss did not improve from 0.19379
# 36/36 [==============================] - 208s 6s/step - loss: 0.1226 - accuracy: 0.8889 - val_loss: 0.1948 - val_accuracy: 0.7129 - lr: 2.0000e-05
# Epoch 36/175
# 36/36 [==============================] - ETA: 0s - loss: 0.1225 - accuracy: 0.8889
# Epoch 00036: val_loss improved from 0.19379 to 0.19378, saving model to ..\scripts\models_h5\siamese_network2c-t2_9notebook.h5
# 36/36 [==============================] - 207s 6s/step - loss: 0.1225 - accuracy: 0.8889 - val_loss: 0.1938 - val_accuracy: 0.7146 - lr: 2.0000e-05
# Epoch 37/175
# 36/36 [==============================] - ETA: 0s - loss: 0.1224 - accuracy: 0.8889
# Epoch 00037: val_loss improved from 0.19378 to 0.19365, saving model to ..\scripts\models_h5\siamese_network2c-t2_9notebook.h5
# 36/36 [==============================] - 207s 6s/step - loss: 0.1224 - accuracy: 0.8889 - val_loss: 0.1937 - val_accuracy: 0.7150 - lr: 2.0000e-05
# Epoch 38/175
# 36/36 [==============================] - ETA: 0s - loss: 0.1224 - accuracy: 0.8889
# Epoch 00038: val_loss did not improve from 0.19365
# 36/36 [==============================] - 209s 6s/step - loss: 0.1224 - accuracy: 0.8889 - val_loss: 0.1940 - val_accuracy: 0.7146 - lr: 2.0000e-05
# Epoch 39/175
# 36/36 [==============================] - ETA: 0s - loss: 0.1223 - accuracy: 0.8889
# Epoch 00039: val_loss improved from 0.19365 to 0.19337, saving model to ..\scripts\models_h5\siamese_network2c-t2_9notebook.h5
# 36/36 [==============================] - 207s 6s/step - loss: 0.1223 - accuracy: 0.8889 - val_loss: 0.1934 - val_accuracy: 0.7154 - lr: 2.0000e-05
# Epoch 40/175
# 36/36 [==============================] - ETA: 0s - loss: 0.1222 - accuracy: 0.8889
# Epoch 00040: val_loss improved from 0.19337 to 0.19322, saving model to ..\scripts\models_h5\siamese_network2c-t2_9notebook.h5
# 36/36 [==============================] - 207s 6s/step - loss: 0.1222 - accuracy: 0.8889 - val_loss: 0.1932 - val_accuracy: 0.7154 - lr: 2.0000e-05
# Epoch 41/175
# 36/36 [==============================] - ETA: 0s - loss: 0.1222 - accuracy: 0.8889
# Epoch 00041: val_loss did not improve from 0.19322
# 36/36 [==============================] - 208s 6s/step - loss: 0.1222 - accuracy: 0.8889 - val_loss: 0.1938 - val_accuracy: 0.7154 - lr: 2.0000e-05
# Epoch 42/175
# 36/36 [==============================] - ETA: 0s - loss: 0.1221 - accuracy: 0.8889
# Epoch 00042: val_loss did not improve from 0.19322
# 36/36 [==============================] - 210s 6s/step - loss: 0.1221 - accuracy: 0.8889 - val_loss: 0.1940 - val_accuracy: 0.7154 - lr: 2.0000e-05
# Epoch 43/175
# 36/36 [==============================] - ETA: 0s - loss: 0.1220 - accuracy: 0.8889
# Epoch 00043: val_loss did not improve from 0.19322
# 36/36 [==============================] - 208s 6s/step - loss: 0.1220 - accuracy: 0.8889 - val_loss: 0.1937 - val_accuracy: 0.7154 - lr: 2.0000e-05
# Epoch 44/175
# 36/36 [==============================] - ETA: 0s - loss: 0.1220 - accuracy: 0.8889
# Epoch 00044: val_loss did not improve from 0.19322
# 36/36 [==============================] - 208s 6s/step - loss: 0.1220 - accuracy: 0.8889 - val_loss: 0.1938 - val_accuracy: 0.7154 - lr: 2.0000e-05
# Epoch 45/175
# 36/36 [==============================] - ETA: 0s - loss: 0.1219 - accuracy: 0.8889
# Epoch 00045: val_loss improved from 0.19322 to 0.19314, saving model to ..\scripts\models_h5\siamese_network2c-t2_9notebook.h5
# 36/36 [==============================] - 207s 6s/step - loss: 0.1219 - accuracy: 0.8889 - val_loss: 0.1931 - val_accuracy: 0.7163 - lr: 2.0000e-05
# Epoch 46/175
# 36/36 [==============================] - ETA: 0s - loss: 0.1219 - accuracy: 0.8889
# Epoch 00046: val_loss improved from 0.19314 to 0.19310, saving model to ..\scripts\models_h5\siamese_network2c-t2_9notebook.h5
# 36/36 [==============================] - 208s 6s/step - loss: 0.1219 - accuracy: 0.8889 - val_loss: 0.1931 - val_accuracy: 0.7163 - lr: 1.0000e-05
# Epoch 47/175
# 36/36 [==============================] - ETA: 0s - loss: 0.1218 - accuracy: 0.8889
# Epoch 00047: val_loss did not improve from 0.19310
# 36/36 [==============================] - 209s 6s/step - loss: 0.1218 - accuracy: 0.8889 - val_loss: 0.1933 - val_accuracy: 0.7163 - lr: 1.0000e-05
# Epoch 48/175
# 36/36 [==============================] - ETA: 0s - loss: 0.1218 - accuracy: 0.8889
# Epoch 00048: val_loss did not improve from 0.19310
# 36/36 [==============================] - 209s 6s/step - loss: 0.1218 - accuracy: 0.8889 - val_loss: 0.1931 - val_accuracy: 0.7163 - lr: 1.0000e-05
# Epoch 49/175
# 36/36 [==============================] - ETA: 0s - loss: 0.1218 - accuracy: 0.8889
# Epoch 00049: val_loss did not improve from 0.19310
# 36/36 [==============================] - 208s 6s/step - loss: 0.1218 - accuracy: 0.8889 - val_loss: 0.1932 - val_accuracy: 0.7163 - lr: 1.0000e-05
# Epoch 50/175
# 36/36 [==============================] - ETA: 0s - loss: 0.1218 - accuracy: 0.8889
# Epoch 00050: val_loss did not improve from 0.19310
# 36/36 [==============================] - 208s 6s/step - loss: 0.1218 - accuracy: 0.8889 - val_loss: 0.1932 - val_accuracy: 0.7163 - lr: 1.0000e-05
# Epoch 51/175
# 36/36 [==============================] - ETA: 0s - loss: 0.1217 - accuracy: 0.8889
# Epoch 00051: val_loss did not improve from 0.19310
# 36/36 [==============================] - 209s 6s/step - loss: 0.1217 - accuracy: 0.8889 - val_loss: 0.1932 - val_accuracy: 0.7167 - lr: 1.0000e-05
# Epoch 52/175
# 36/36 [==============================] - ETA: 0s - loss: 0.1217 - accuracy: 0.8889
# Epoch 00052: val_loss did not improve from 0.19310
# 36/36 [==============================] - 208s 6s/step - loss: 0.1217 - accuracy: 0.8889 - val_loss: 0.1936 - val_accuracy: 0.7163 - lr: 1.0000e-05
# Epoch 53/175
# 36/36 [==============================] - ETA: 0s - loss: 0.1217 - accuracy: 0.8889
# Epoch 00053: val_loss did not improve from 0.19310
# 36/36 [==============================] - 208s 6s/step - loss: 0.1217 - accuracy: 0.8889 - val_loss: 0.1932 - val_accuracy: 0.7167 - lr: 1.0000e-05
# Epoch 54/175
# 36/36 [==============================] - ETA: 0s - loss: 0.1216 - accuracy: 0.8889
# Epoch 00054: val_loss improved from 0.19310 to 0.19309, saving model to ..\scripts\models_h5\siamese_network2c-t2_9notebook.h5
# 36/36 [==============================] - 208s 6s/step - loss: 0.1216 - accuracy: 0.8889 - val_loss: 0.1931 - val_accuracy: 0.7175 - lr: 1.0000e-05
# Epoch 55/175
# 36/36 [==============================] - ETA: 0s - loss: 0.1216 - accuracy: 0.8889
# Epoch 00055: val_loss improved from 0.19309 to 0.19297, saving model to ..\scripts\models_h5\siamese_network2c-t2_9notebook.h5
# 36/36 [==============================] - 209s 6s/step - loss: 0.1216 - accuracy: 0.8889 - val_loss: 0.1930 - val_accuracy: 0.7175 - lr: 1.0000e-05
# Epoch 56/175
# 36/36 [==============================] - ETA: 0s - loss: 0.1216 - accuracy: 0.8889
# Epoch 00056: val_loss did not improve from 0.19297
# 36/36 [==============================] - 208s 6s/step - loss: 0.1216 - accuracy: 0.8889 - val_loss: 0.1932 - val_accuracy: 0.7175 - lr: 1.0000e-05
# Epoch 57/175
# 36/36 [==============================] - ETA: 0s - loss: 0.1216 - accuracy: 0.8889
# Epoch 00057: val_loss improved from 0.19297 to 0.19289, saving model to ..\scripts\models_h5\siamese_network2c-t2_9notebook.h5
# 36/36 [==============================] - 209s 6s/step - loss: 0.1216 - accuracy: 0.8889 - val_loss: 0.1929 - val_accuracy: 0.7175 - lr: 1.0000e-05
# Epoch 58/175
# 36/36 [==============================] - ETA: 0s - loss: 0.1215 - accuracy: 0.8889
# Epoch 00058: val_loss improved from 0.19289 to 0.19287, saving model to ..\scripts\models_h5\siamese_network2c-t2_9notebook.h5
# 36/36 [==============================] - 208s 6s/step - loss: 0.1215 - accuracy: 0.8889 - val_loss: 0.1929 - val_accuracy: 0.7171 - lr: 1.0000e-05
# Epoch 59/175
# 36/36 [==============================] - ETA: 0s - loss: 0.1215 - accuracy: 0.8889
# Epoch 00059: val_loss did not improve from 0.19287
# 36/36 [==============================] - 210s 6s/step - loss: 0.1215 - accuracy: 0.8889 - val_loss: 0.1933 - val_accuracy: 0.7175 - lr: 1.0000e-05
# Epoch 60/175
# 36/36 [==============================] - ETA: 0s - loss: 0.1215 - accuracy: 0.8889
# Epoch 00060: val_loss did not improve from 0.19287
# 36/36 [==============================] - 208s 6s/step - loss: 0.1215 - accuracy: 0.8889 - val_loss: 0.1931 - val_accuracy: 0.7175 - lr: 1.0000e-05
# Epoch 61/175
# 36/36 [==============================] - ETA: 0s - loss: 0.1214 - accuracy: 0.8889
# Epoch 00061: val_loss did not improve from 0.19287
# 36/36 [==============================] - 207s 6s/step - loss: 0.1214 - accuracy: 0.8889 - val_loss: 0.1930 - val_accuracy: 0.7171 - lr: 1.0000e-05
# Epoch 62/175
# 36/36 [==============================] - ETA: 0s - loss: 0.1214 - accuracy: 0.8889
# Epoch 00062: val_loss improved from 0.19287 to 0.19279, saving model to ..\scripts\models_h5\siamese_network2c-t2_9notebook.h5
# 36/36 [==============================] - 209s 6s/step - loss: 0.1214 - accuracy: 0.8889 - val_loss: 0.1928 - val_accuracy: 0.7175 - lr: 1.0000e-05
# Epoch 63/175
# 36/36 [==============================] - ETA: 0s - loss: 0.1214 - accuracy: 0.8889
# Epoch 00063: val_loss did not improve from 0.19279
# 36/36 [==============================] - 207s 6s/step - loss: 0.1214 - accuracy: 0.8889 - val_loss: 0.1931 - val_accuracy: 0.7175 - lr: 1.0000e-05
# Epoch 64/175
# 36/36 [==============================] - ETA: 0s - loss: 0.1213 - accuracy: 0.8889
# Epoch 00064: val_loss did not improve from 0.19279
# 36/36 [==============================] - 210s 6s/step - loss: 0.1213 - accuracy: 0.8889 - val_loss: 0.1932 - val_accuracy: 0.7175 - lr: 1.0000e-05
# Epoch 65/175
# 36/36 [==============================] - ETA: 0s - loss: 0.1213 - accuracy: 0.8889
# Epoch 00065: val_loss did not improve from 0.19279
# 36/36 [==============================] - 208s 6s/step - loss: 0.1213 - accuracy: 0.8889 - val_loss: 0.1932 - val_accuracy: 0.7175 - lr: 1.0000e-05
# Epoch 66/175
# 36/36 [==============================] - ETA: 0s - loss: 0.1213 - accuracy: 0.8889
# Epoch 00066: val_loss improved from 0.19279 to 0.19272, saving model to ..\scripts\models_h5\siamese_network2c-t2_9notebook.h5
# 36/36 [==============================] - 207s 6s/step - loss: 0.1213 - accuracy: 0.8889 - val_loss: 0.1927 - val_accuracy: 0.7179 - lr: 1.0000e-05
# Epoch 67/175
# 36/36 [==============================] - ETA: 0s - loss: 0.1213 - accuracy: 0.8889
# Epoch 00067: val_loss did not improve from 0.19272
# 36/36 [==============================] - 209s 6s/step - loss: 0.1213 - accuracy: 0.8889 - val_loss: 0.1928 - val_accuracy: 0.7179 - lr: 1.0000e-05
# Epoch 68/175
# 36/36 [==============================] - ETA: 0s - loss: 0.1212 - accuracy: 0.8889
# Epoch 00068: val_loss improved from 0.19272 to 0.19266, saving model to ..\scripts\models_h5\siamese_network2c-t2_9notebook.h5
# 36/36 [==============================] - 208s 6s/step - loss: 0.1212 - accuracy: 0.8889 - val_loss: 0.1927 - val_accuracy: 0.7183 - lr: 1.0000e-05
# Epoch 69/175
# 36/36 [==============================] - ETA: 0s - loss: 0.1212 - accuracy: 0.8889
# Epoch 00069: val_loss did not improve from 0.19266
# 36/36 [==============================] - 209s 6s/step - loss: 0.1212 - accuracy: 0.8889 - val_loss: 0.1927 - val_accuracy: 0.7183 - lr: 1.0000e-05
# Epoch 70/175
# 36/36 [==============================] - ETA: 0s - loss: 0.1212 - accuracy: 0.8889
# Epoch 00070: val_loss did not improve from 0.19266
# 36/36 [==============================] - 208s 6s/step - loss: 0.1212 - accuracy: 0.8889 - val_loss: 0.1931 - val_accuracy: 0.7179 - lr: 1.0000e-05
# Epoch 71/175
# 36/36 [==============================] - ETA: 0s - loss: 0.1211 - accuracy: 0.8889
# Epoch 00071: val_loss did not improve from 0.19266
# 36/36 [==============================] - 208s 6s/step - loss: 0.1211 - accuracy: 0.8889 - val_loss: 0.1928 - val_accuracy: 0.7183 - lr: 1.0000e-05
# Epoch 72/175
# 36/36 [==============================] - ETA: 0s - loss: 0.1211 - accuracy: 0.8889
# Epoch 00072: val_loss did not improve from 0.19266
# 36/36 [==============================] - 207s 6s/step - loss: 0.1211 - accuracy: 0.8889 - val_loss: 0.1928 - val_accuracy: 0.7183 - lr: 1.0000e-05
# Epoch 73/175
# 36/36 [==============================] - ETA: 0s - loss: 0.1211 - accuracy: 0.8889
# Epoch 00073: val_loss did not improve from 0.19266
# 36/36 [==============================] - 211s 6s/step - loss: 0.1211 - accuracy: 0.8889 - val_loss: 0.1931 - val_accuracy: 0.7183 - lr: 1.0000e-05
# Epoch 74/175
# 36/36 [==============================] - ETA: 0s - loss: 0.1211 - accuracy: 0.8889
# Epoch 00074: val_loss did not improve from 0.19266
# 36/36 [==============================] - 206s 6s/step - loss: 0.1211 - accuracy: 0.8889 - val_loss: 0.1927 - val_accuracy: 0.7192 - lr: 1.0000e-05
# Epoch 75/175
# 36/36 [==============================] - ETA: 0s - loss: 0.1210 - accuracy: 0.8889
# Epoch 00075: val_loss did not improve from 0.19266
# 36/36 [==============================] - 206s 6s/step - loss: 0.1210 - accuracy: 0.8889 - val_loss: 0.1927 - val_accuracy: 0.7196 - lr: 1.0000e-05
# Epoch 76/175
# 36/36 [==============================] - ETA: 0s - loss: 0.1210 - accuracy: 0.8889
# Epoch 00076: val_loss improved from 0.19266 to 0.19261, saving model to ..\scripts\models_h5\siamese_network2c-t2_9notebook.h5
# 36/36 [==============================] - 209s 6s/step - loss: 0.1210 - accuracy: 0.8889 - val_loss: 0.1926 - val_accuracy: 0.7200 - lr: 1.0000e-05
# Epoch 77/175
# 36/36 [==============================] - ETA: 0s - loss: 0.1210 - accuracy: 0.8889
# Epoch 00077: val_loss did not improve from 0.19261
# 36/36 [==============================] - 210s 6s/step - loss: 0.1210 - accuracy: 0.8889 - val_loss: 0.1927 - val_accuracy: 0.7200 - lr: 1.0000e-05
# Epoch 78/175
# 36/36 [==============================] - ETA: 0s - loss: 0.1209 - accuracy: 0.8889
# Epoch 00078: val_loss improved from 0.19261 to 0.19250, saving model to ..\scripts\models_h5\siamese_network2c-t2_9notebook.h5
# 36/36 [==============================] - 206s 6s/step - loss: 0.1209 - accuracy: 0.8889 - val_loss: 0.1925 - val_accuracy: 0.7204 - lr: 1.0000e-05
# Epoch 79/175
# 36/36 [==============================] - ETA: 0s - loss: 0.1209 - accuracy: 0.8889
# Epoch 00079: val_loss did not improve from 0.19250
# 36/36 [==============================] - 207s 6s/step - loss: 0.1209 - accuracy: 0.8889 - val_loss: 0.1925 - val_accuracy: 0.7204 - lr: 1.0000e-05
# Epoch 80/175
# 36/36 [==============================] - ETA: 0s - loss: 0.1209 - accuracy: 0.8889
# Epoch 00080: val_loss did not improve from 0.19250
# 36/36 [==============================] - 206s 6s/step - loss: 0.1209 - accuracy: 0.8889 - val_loss: 0.1927 - val_accuracy: 0.7204 - lr: 1.0000e-05
# Epoch 81/175
# 36/36 [==============================] - ETA: 0s - loss: 0.1208 - accuracy: 0.8889
# Epoch 00081: val_loss improved from 0.19250 to 0.19233, saving model to ..\scripts\models_h5\siamese_network2c-t2_9notebook.h5
# 36/36 [==============================] - 207s 6s/step - loss: 0.1208 - accuracy: 0.8889 - val_loss: 0.1923 - val_accuracy: 0.7212 - lr: 1.0000e-05
# Epoch 82/175
# 36/36 [==============================] - ETA: 0s - loss: 0.1208 - accuracy: 0.8889
# Epoch 00082: val_loss did not improve from 0.19233
# 36/36 [==============================] - 207s 6s/step - loss: 0.1208 - accuracy: 0.8889 - val_loss: 0.1925 - val_accuracy: 0.7212 - lr: 1.0000e-05
# Epoch 83/175
# 36/36 [==============================] - ETA: 0s - loss: 0.1208 - accuracy: 0.8889
# Epoch 00083: val_loss did not improve from 0.19233
# 36/36 [==============================] - 206s 6s/step - loss: 0.1208 - accuracy: 0.8889 - val_loss: 0.1925 - val_accuracy: 0.7212 - lr: 1.0000e-05
# Epoch 84/175
# 36/36 [==============================] - ETA: 0s - loss: 0.1207 - accuracy: 0.8889
# Epoch 00084: val_loss did not improve from 0.19233
# 36/36 [==============================] - 208s 6s/step - loss: 0.1207 - accuracy: 0.8889 - val_loss: 0.1926 - val_accuracy: 0.7212 - lr: 1.0000e-05
# Epoch 85/175
# 36/36 [==============================] - ETA: 0s - loss: 0.1207 - accuracy: 0.8889
# Epoch 00085: val_loss did not improve from 0.19233
# 36/36 [==============================] - 207s 6s/step - loss: 0.1207 - accuracy: 0.8889 - val_loss: 0.1926 - val_accuracy: 0.7212 - lr: 1.0000e-05
# Epoch 86/175
# 36/36 [==============================] - ETA: 0s - loss: 0.1207 - accuracy: 0.8889
# Epoch 00086: val_loss improved from 0.19233 to 0.19228, saving model to ..\scripts\models_h5\siamese_network2c-t2_9notebook.h5
# 36/36 [==============================] - 207s 6s/step - loss: 0.1207 - accuracy: 0.8889 - val_loss: 0.1923 - val_accuracy: 0.7221 - lr: 1.0000e-05
# Epoch 87/175
# 36/36 [==============================] - ETA: 0s - loss: 0.1207 - accuracy: 0.8889
# Epoch 00087: val_loss did not improve from 0.19228
# 36/36 [==============================] - 207s 6s/step - loss: 0.1207 - accuracy: 0.8889 - val_loss: 0.1925 - val_accuracy: 0.7217 - lr: 1.0000e-05
# Epoch 88/175
# 36/36 [==============================] - ETA: 0s - loss: 0.1206 - accuracy: 0.8889
# Epoch 00088: val_loss did not improve from 0.19228
# 36/36 [==============================] - 206s 6s/step - loss: 0.1206 - accuracy: 0.8889 - val_loss: 0.1923 - val_accuracy: 0.7221 - lr: 1.0000e-05
# Epoch 89/175
# 36/36 [==============================] - ETA: 0s - loss: 0.1206 - accuracy: 0.8889
# Epoch 00089: val_loss did not improve from 0.19228
# 36/36 [==============================] - 206s 6s/step - loss: 0.1206 - accuracy: 0.8889 - val_loss: 0.1928 - val_accuracy: 0.7217 - lr: 1.0000e-05
# Epoch 90/175
# 36/36 [==============================] - ETA: 0s - loss: 0.1206 - accuracy: 0.8889
# Epoch 00090: val_loss improved from 0.19228 to 0.19212, saving model to ..\scripts\models_h5\siamese_network2c-t2_9notebook.h5
# 36/36 [==============================] - 207s 6s/step - loss: 0.1206 - accuracy: 0.8889 - val_loss: 0.1921 - val_accuracy: 0.7225 - lr: 1.0000e-05
# Epoch 91/175
# 36/36 [==============================] - ETA: 0s - loss: 0.1205 - accuracy: 0.8889
# Epoch 00091: val_loss did not improve from 0.19212
# 36/36 [==============================] - 207s 6s/step - loss: 0.1205 - accuracy: 0.8889 - val_loss: 0.1923 - val_accuracy: 0.7225 - lr: 1.0000e-05
# Epoch 92/175
# 36/36 [==============================] - ETA: 0s - loss: 0.1205 - accuracy: 0.8889
# Epoch 00092: val_loss did not improve from 0.19212
# 36/36 [==============================] - 206s 6s/step - loss: 0.1205 - accuracy: 0.8889 - val_loss: 0.1925 - val_accuracy: 0.7221 - lr: 1.0000e-05
# Epoch 93/175
# 36/36 [==============================] - ETA: 0s - loss: 0.1205 - accuracy: 0.8889
# Epoch 00093: val_loss did not improve from 0.19212
# 36/36 [==============================] - 207s 6s/step - loss: 0.1205 - accuracy: 0.8889 - val_loss: 0.1927 - val_accuracy: 0.7221 - lr: 1.0000e-05
# Epoch 94/175
# 36/36 [==============================] - ETA: 0s - loss: 0.1205 - accuracy: 0.8889
# Epoch 00094: val_loss did not improve from 0.19212
# 36/36 [==============================] - 208s 6s/step - loss: 0.1205 - accuracy: 0.8889 - val_loss: 0.1925 - val_accuracy: 0.7225 - lr: 1.0000e-05
# Epoch 95/175
# 36/36 [==============================] - ETA: 0s - loss: 0.1204 - accuracy: 0.8889
# Epoch 00095: val_loss did not improve from 0.19212
# 36/36 [==============================] - 206s 6s/step - loss: 0.1204 - accuracy: 0.8889 - val_loss: 0.1925 - val_accuracy: 0.7225 - lr: 1.0000e-05
# Epoch 96/175
# 36/36 [==============================] - ETA: 0s - loss: 0.1204 - accuracy: 0.8889
# Epoch 00096: val_loss did not improve from 0.19212
# 36/36 [==============================] - 207s 6s/step - loss: 0.1204 - accuracy: 0.8889 - val_loss: 0.1923 - val_accuracy: 0.7233 - lr: 1.0000e-05
# Epoch 97/175
# 36/36 [==============================] - ETA: 0s - loss: 0.1204 - accuracy: 0.8889
# Epoch 00097: val_loss did not improve from 0.19212
# 36/36 [==============================] - 208s 6s/step - loss: 0.1204 - accuracy: 0.8889 - val_loss: 0.1923 - val_accuracy: 0.7242 - lr: 1.0000e-05
# Epoch 98/175
# 36/36 [==============================] - ETA: 0s - loss: 0.1204 - accuracy: 0.8889
# Epoch 00098: val_loss did not improve from 0.19212
# 36/36 [==============================] - 206s 6s/step - loss: 0.1204 - accuracy: 0.8889 - val_loss: 0.1925 - val_accuracy: 0.7233 - lr: 1.0000e-05
# Epoch 99/175
# 36/36 [==============================] - ETA: 0s - loss: 0.1203 - accuracy: 0.8889
# Epoch 00099: val_loss improved from 0.19212 to 0.19203, saving model to ..\scripts\models_h5\siamese_network2c-t2_9notebook.h5
# 36/36 [==============================] - 207s 6s/step - loss: 0.1203 - accuracy: 0.8889 - val_loss: 0.1920 - val_accuracy: 0.7246 - lr: 1.0000e-05
# Epoch 100/175
# 36/36 [==============================] - ETA: 0s - loss: 0.1203 - accuracy: 0.8889
# Epoch 00100: val_loss improved from 0.19203 to 0.19193, saving model to ..\scripts\models_h5\siamese_network2c-t2_9notebook.h5
# 36/36 [==============================] - 207s 6s/step - loss: 0.1203 - accuracy: 0.8889 - val_loss: 0.1919 - val_accuracy: 0.7246 - lr: 1.0000e-05
# Epoch 101/175
# 36/36 [==============================] - ETA: 0s - loss: 0.1202 - accuracy: 0.8889
# Epoch 00101: val_loss improved from 0.19193 to 0.19190, saving model to ..\scripts\models_h5\siamese_network2c-t2_9notebook.h5
# 36/36 [==============================] - 206s 6s/step - loss: 0.1202 - accuracy: 0.8889 - val_loss: 0.1919 - val_accuracy: 0.7246 - lr: 1.0000e-05
# Epoch 102/175
# 36/36 [==============================] - ETA: 0s - loss: 0.1202 - accuracy: 0.8889
# Epoch 00102: val_loss did not improve from 0.19190
# 36/36 [==============================] - 206s 6s/step - loss: 0.1202 - accuracy: 0.8889 - val_loss: 0.1921 - val_accuracy: 0.7246 - lr: 1.0000e-05
# Epoch 103/175
# 36/36 [==============================] - ETA: 0s - loss: 0.1202 - accuracy: 0.8889
# Epoch 00103: val_loss improved from 0.19190 to 0.19170, saving model to ..\scripts\models_h5\siamese_network2c-t2_9notebook.h5
# 36/36 [==============================] - 206s 6s/step - loss: 0.1202 - accuracy: 0.8889 - val_loss: 0.1917 - val_accuracy: 0.7258 - lr: 1.0000e-05
# Epoch 104/175
# 36/36 [==============================] - ETA: 0s - loss: 0.1202 - accuracy: 0.8889
# Epoch 00104: val_loss did not improve from 0.19170
# 36/36 [==============================] - 206s 6s/step - loss: 0.1202 - accuracy: 0.8889 - val_loss: 0.1923 - val_accuracy: 0.7246 - lr: 1.0000e-05
# Epoch 105/175
# 36/36 [==============================] - ETA: 0s - loss: 0.1201 - accuracy: 0.8889
# Epoch 00105: val_loss did not improve from 0.19170
# 36/36 [==============================] - 207s 6s/step - loss: 0.1201 - accuracy: 0.8889 - val_loss: 0.1919 - val_accuracy: 0.7254 - lr: 1.0000e-05
# Epoch 106/175
# 36/36 [==============================] - ETA: 0s - loss: 0.1201 - accuracy: 0.8889
# Epoch 00106: val_loss did not improve from 0.19170
# 36/36 [==============================] - 207s 6s/step - loss: 0.1201 - accuracy: 0.8889 - val_loss: 0.1918 - val_accuracy: 0.7262 - lr: 1.0000e-05
# Epoch 107/175
# 36/36 [==============================] - ETA: 0s - loss: 0.1201 - accuracy: 0.8889
# Epoch 00107: val_loss did not improve from 0.19170
# 36/36 [==============================] - 211s 6s/step - loss: 0.1201 - accuracy: 0.8889 - val_loss: 0.1921 - val_accuracy: 0.7254 - lr: 1.0000e-05
# Epoch 108/175
# 36/36 [==============================] - ETA: 0s - loss: 0.1200 - accuracy: 0.8889
# Epoch 00108: val_loss did not improve from 0.19170
# 36/36 [==============================] - 208s 6s/step - loss: 0.1200 - accuracy: 0.8889 - val_loss: 0.1919 - val_accuracy: 0.7262 - lr: 1.0000e-05
# Epoch 109/175
# 36/36 [==============================] - ETA: 0s - loss: 0.1200 - accuracy: 0.8889
# Epoch 00109: val_loss did not improve from 0.19170
# 36/36 [==============================] - 206s 6s/step - loss: 0.1200 - accuracy: 0.8889 - val_loss: 0.1920 - val_accuracy: 0.7262 - lr: 1.0000e-05
# Epoch 110/175
# 36/36 [==============================] - ETA: 0s - loss: 0.1200 - accuracy: 0.8889
# Epoch 00110: val_loss did not improve from 0.19170
# 36/36 [==============================] - 206s 6s/step - loss: 0.1200 - accuracy: 0.8889 - val_loss: 0.1918 - val_accuracy: 0.7258 - lr: 1.0000e-05
# Epoch 111/175
# 36/36 [==============================] - ETA: 0s - loss: 0.1199 - accuracy: 0.8889
# Epoch 00111: val_loss did not improve from 0.19170
# 36/36 [==============================] - 206s 6s/step - loss: 0.1199 - accuracy: 0.8889 - val_loss: 0.1919 - val_accuracy: 0.7258 - lr: 1.0000e-05
# Epoch 112/175
# 36/36 [==============================] - ETA: 0s - loss: 0.1199 - accuracy: 0.8889
# Epoch 00112: val_loss did not improve from 0.19170
# 36/36 [==============================] - 208s 6s/step - loss: 0.1199 - accuracy: 0.8889 - val_loss: 0.1917 - val_accuracy: 0.7258 - lr: 1.0000e-05
# Epoch 113/175
# 36/36 [==============================] - ETA: 0s - loss: 0.1199 - accuracy: 0.8889
# Epoch 00113: val_loss did not improve from 0.19170
# 36/36 [==============================] - 206s 6s/step - loss: 0.1199 - accuracy: 0.8889 - val_loss: 0.1918 - val_accuracy: 0.7258 - lr: 1.0000e-05
# Epoch 00113: early stopping

# %%
results = siamese.evaluate([x_test_1, x_test_2], labels_test)
print("test loss, test acc:", results)
# Out:
# 75/75 [==============================] - 167s 2s/step - loss: 0.1387 - accuracy: 0.9046
# test loss, test acc: [0.13868451118469238, 0.9045833349227905]

# %%
Y_pred = siamese.predict([x_test_1, x_test_2]).squeeze()
# 返回的是TRUE或FALSE,没有标签数据怎么知道他被分到哪儿个类中？
y_pred = Y_pred > 0.5
# x1,和x2是否匹配：匹配1，不匹配0
y_test = labels_test
print("\nEvaluate on validation data")
Accuracy=accuracy_score(y_test, y_pred)
Precision=precision_score(y_test, y_pred, average='weighted')
Recall=recall_score(y_test, y_pred, average='weighted')
ROC_AUC=roc_auc_score(y_test, y_pred, average='weighted')
F1=f1_score(y_test, y_pred, average='weighted')
print("Accuracy:", Accuracy)
print("Precision:", Precision)
print("Recall:", Recall)
print("ROC AUC:", ROC_AUC)
print("F1:",F1 )
# Out:
# Evaluate on validation data
# Accuracy: 0.9045833333333333
# Precision: 0.9193252361673414
# Recall: 0.9045833333333333
# ROC AUC: 0.9045833333333333
# F1: 0.9037372742200328

# %%
y_pred = [1 if i else 0 for i in y_pred]
pred_labels = []

for i in range(0, len(y_pred)):
    if y_pred[i] == 1:
        pred_labels += [source_labels_test[i]]
    else:
        if source_labels_test[i] == 1:
            pred_labels += [0.0]
        else:
            pred_labels += [1.0]
a = x_test_1.tolist()
df = pd.DataFrame({"image": a, "label_{}".format(teacher_id): pred_labels})
if not os.path.exists(pre_results_path):
    os.makedirs(pre_results_path)
df.to_excel(os.path.join(pre_results_path,"{}_{}_{}.xlsx".format(epochs,teacher_id,shot)),index=False)

# %%
cm = confusion_matrix(y_test, y_pred)
cm_display = ConfusionMatrixDisplay(cm).plot()
plt.show()
tn, fp, fn, tp = cm.ravel()
specificity = tn / (tn + fp)
print("Specificity:", specificity)
data_list=[{"Accuracy":Accuracy,"Precision":Precision,"Recall":Recall,"ROC_AUC":ROC_AUC,"tn":tn,"fp":fp,"fn":fn,"tp":tp,"specificity":specificity}]
df=pd.DataFrame(data_list)

filepath=os.path.join(base_dir,r"acc_{}_{}".format(all_teachers,shot))
if not os.path.exists(filepath):
    os.mkdir(filepath)
df.to_excel(os.path.join(filepath,"{}_{}.xlsx".format(teacher_id,shot)),index=False)
tf.keras.backend.clear_session()
# Out:
# Specificity: 0.9983333333333333
