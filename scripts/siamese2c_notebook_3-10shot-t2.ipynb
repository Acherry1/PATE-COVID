# %%
# -*- coding: utf-8 -*-
import utils as utils

import tensorflow as tf
from tensorflow.keras.layers import Dense, Input, Flatten, Lambda
from tensorflow.keras.models import Model
from tensorflow.keras.optimizers import Adam
from sklearn.metrics import accuracy_score, precision_score, recall_score, roc_auc_score, f1_score

from sklearn.metrics import confusion_matrix
from sklearn.metrics import ConfusionMatrixDisplay

import numpy as np
import os

from tensorflow.keras.callbacks import EarlyStopping, ModelCheckpoint, ReduceLROnPlateau
import matplotlib.pyplot as plt
import logging

logger = tf.get_logger()
logger.setLevel(logging.ERROR)

# %%
all_teachers=3
teacher_id = 2
epochs = 175
shot = 10
SIAMESE_MODEL_NAME = '..\scripts\models_h5\siamese_network2c-t{}_{}notebook.h5'.format(teacher_id,shot)
EMBEDDING_MODEL_NAME = 'embedding_network2w_0801.h5'
if os.path.exists(SIAMESE_MODEL_NAME):
    os.remove(SIAMESE_MODEL_NAME)

# %%
base_dir = r"F:\chest project dataset\dataset"
dataset_path = os.path.join( r"F:\chest project dataset\auto_datasets", r"auto_t{}_{}\t{}-{}".format(all_teachers,shot,teacher_id, shot))
result_file_path = os.path.join(base_dir, r"true_result_xlsx")
pre_results_path = os.path.join(base_dir, r"teacher_results_xlsx","result_{}_{}".format(all_teachers,shot))
train_image_list, train_y_list = utils.load_images(dataset_path, 'train', (100, 100))
print("The train set contains", len(train_image_list))
# Out:
# Found 20 images belonging to 2 classes.
# The train set contains 20

# %%
test_path = r"F:\chest project dataset\dataset\pretrain_2c_0727"
valid_image_list, valid_y_list = utils.load_images(test_path, 'valid', (100, 100))
print("The valid set contains", len(valid_image_list))
# Out:
# Found 1200 images belonging to 2 classes.
# The valid set contains 1200

# %%
test_image_list, test_y_list = utils.load_images(test_path, 'test', (100, 100))
print("The test set contains", len(test_image_list))
# Out:
# Found 1200 images belonging to 2 classes.
# The test set contains 1200

# %%
# make train pairs
pairs_train, labels_train, source_labels_train, true_labels_train = utils.make_pairs(train_image_list, train_y_list)

# make validation pairs
pairs_val, labels_val, source_labels_val, true_labels_val = utils.make_pairs(valid_image_list, valid_y_list)

# make validation pairs
pairs_test, labels_test, source_labels_test, true_labels_test = utils.make_pairs(test_image_list, test_y_list)
# Out:
# num_classes: 2
# num_classes: 2
# num_classes: 2

# %%
import pandas as pd

# %%
x_train_1 = pairs_train[:, 0]  # x1(如何给标签带上)
x_train_2 = pairs_train[:, 1]  # x2
print("number of pairs for train", np.shape(x_train_1)[0])

x_val_1 = pairs_val[:, 0]
x_val_2 = pairs_val[:, 1]
print("number of pairs for validation", np.shape(x_val_1)[0])

x_test_1 = pairs_test[:, 0]
x_test_2 = pairs_test[:, 1]
# print(x_test_1)
print("number of pairs for test", np.shape(x_test_1)[0])
# Out:
# number of pairs for train 40
# number of pairs for validation 2400
# number of pairs for test 2400

# %%
if not os.path.exists(result_file_path):
    os.makedirs(result_file_path)
result_xlsx=os.path.join(result_file_path,"true_labels.xlsx")
if not os.path.exists(result_xlsx):
    test_1_image_list = x_test_1.tolist()
    df = pd.DataFrame({"image": test_1_image_list, "true_label": true_labels_test})
    df.to_excel(result_xlsx, index=False)
    df = pd.read_excel(result_xlsx)
    df.drop_duplicates(inplace=True)
    df.to_excel(result_xlsx, index=False)

# %%
tf.compat.v1.reset_default_graph()

input_1 = Input((100, 100, 3))
input_2 = Input((100, 100, 3))

embedding_network = tf.keras.models.load_model(EMBEDDING_MODEL_NAME)
embedding_network.trainable = False

model = tf.keras.Sequential()
for layer in embedding_network.layers:
    model.add(layer)

model.add(Flatten(name='flat'))
model.add(Dense(5120, name='den', activation='sigmoid', kernel_regularizer='l2'))

output_1 = model(input_1)
output_2 = model(input_2)

merge_layer = Lambda(utils.manhattan_distance)([output_1, output_2])
output_layer = Dense(1, activation="sigmoid")(merge_layer)
siamese = Model(inputs=[input_1, input_2], outputs=output_layer)
siamese.summary()
# Out:
# Model: "model"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ==================================================================================================
#  input_1 (InputLayer)           [(None, 100, 100, 3  0           []
#                                 )]
#
#  input_2 (InputLayer)           [(None, 100, 100, 3  0           []
#                                 )]
#
#  sequential (Sequential)        (None, 5120)         14739266    ['input_1[0][0]',
#                                                                   'input_2[0][0]']
#
#  lambda (Lambda)                (None, 1)            0           ['sequential[0][0]',
#                                                                   'sequential[1][0]']
#
#  dense (Dense)                  (None, 1)            2           ['lambda[0][0]']
#
# ==================================================================================================
# Total params: 14,739,268
# Trainable params: 15,362
# Non-trainable params: 14,723,906
# __________________________________________________________________________________________________

# %%
reduce_lr = ReduceLROnPlateau(monitor='val_loss', factor=0.2, patience=5, min_lr=0.00001)

early_stopping = EarlyStopping(monitor='val_loss', patience=10, verbose=1, min_delta=0.0001)

checkpointer = ModelCheckpoint(filepath=SIAMESE_MODEL_NAME, verbose=1,
                               save_best_only=True)

# %%
optimizer = Adam(learning_rate=0.0001)
siamese.compile(loss=utils.loss(1), optimizer=optimizer, metrics=["accuracy"])
# siamese.compile(loss='sparse_categorical_crossentropy', optimizer=optimizer, metrics=["accuracy"])

siamese.summary()
history = siamese.fit([x_train_1, x_train_2],
                      labels_train,
                      validation_data=([x_val_1, x_val_2], labels_val),
                      batch_size=1,
                      epochs=epochs,  # 175 for contrastive 100 for cross ent
                      callbacks=[checkpointer, early_stopping, reduce_lr]
                      )
# print()
# Plot the accuracy
# utils.plt_metric(history=history.history, metric="accuracy", title="Model accuracy")

# Plot the constrastive loss
# utils.plt_metric(history=history.history, metric="loss", title="Constrastive Loss")
# Out:
# Model: "model"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ==================================================================================================
#  input_1 (InputLayer)           [(None, 100, 100, 3  0           []
#                                 )]
#
#  input_2 (InputLayer)           [(None, 100, 100, 3  0           []
#                                 )]
#
#  sequential (Sequential)        (None, 5120)         14739266    ['input_1[0][0]',
#                                                                   'input_2[0][0]']
#
#  lambda (Lambda)                (None, 1)            0           ['sequential[0][0]',
#                                                                   'sequential[1][0]']
#
#  dense (Dense)                  (None, 1)            2           ['lambda[0][0]']
#
# ==================================================================================================
# Total params: 14,739,268
# Trainable params: 15,362
# Non-trainable params: 14,723,906
# __________________________________________________________________________________________________
# Epoch 1/175
# 40/40 [==============================] - ETA: 0s - loss: 0.3023 - accuracy: 0.5250
# Epoch 00001: val_loss improved from inf to 0.32203, saving model to ..\scripts\models_h5\siamese_network2c-t2_10notebook.h5
# 40/40 [==============================] - 220s 6s/step - loss: 0.3023 - accuracy: 0.5250 - val_loss: 0.3220 - val_accuracy: 0.5096 - lr: 1.0000e-04
# Epoch 2/175
# 40/40 [==============================] - ETA: 0s - loss: 0.2807 - accuracy: 0.5250
# Epoch 00002: val_loss improved from 0.32203 to 0.30114, saving model to ..\scripts\models_h5\siamese_network2c-t2_10notebook.h5
# 40/40 [==============================] - 272s 7s/step - loss: 0.2807 - accuracy: 0.5250 - val_loss: 0.3011 - val_accuracy: 0.5208 - lr: 1.0000e-04
# Epoch 3/175
# 40/40 [==============================] - ETA: 0s - loss: 0.2588 - accuracy: 0.5500
# Epoch 00003: val_loss improved from 0.30114 to 0.27906, saving model to ..\scripts\models_h5\siamese_network2c-t2_10notebook.h5
# 40/40 [==============================] - 324s 8s/step - loss: 0.2588 - accuracy: 0.5500 - val_loss: 0.2791 - val_accuracy: 0.5408 - lr: 1.0000e-04
# Epoch 4/175
# 40/40 [==============================] - ETA: 0s - loss: 0.2336 - accuracy: 0.5500
# Epoch 00004: val_loss improved from 0.27906 to 0.25549, saving model to ..\scripts\models_h5\siamese_network2c-t2_10notebook.h5
# 40/40 [==============================] - 405s 10s/step - loss: 0.2336 - accuracy: 0.5500 - val_loss: 0.2555 - val_accuracy: 0.5642 - lr: 1.0000e-04
# Epoch 5/175
# 40/40 [==============================] - ETA: 0s - loss: 0.2073 - accuracy: 0.5500
# Epoch 00005: val_loss improved from 0.25549 to 0.23268, saving model to ..\scripts\models_h5\siamese_network2c-t2_10notebook.h5
# 40/40 [==============================] - 399s 10s/step - loss: 0.2073 - accuracy: 0.5500 - val_loss: 0.2327 - val_accuracy: 0.5900 - lr: 1.0000e-04
# Epoch 6/175
# 40/40 [==============================] - ETA: 0s - loss: 0.1829 - accuracy: 0.6000
# Epoch 00006: val_loss improved from 0.23268 to 0.21086, saving model to ..\scripts\models_h5\siamese_network2c-t2_10notebook.h5
# 40/40 [==============================] - 404s 10s/step - loss: 0.1829 - accuracy: 0.6000 - val_loss: 0.2109 - val_accuracy: 0.6242 - lr: 1.0000e-04
# Epoch 7/175
# 40/40 [==============================] - ETA: 0s - loss: 0.1728 - accuracy: 0.6500
# Epoch 00007: val_loss improved from 0.21086 to 0.20289, saving model to ..\scripts\models_h5\siamese_network2c-t2_10notebook.h5
# 40/40 [==============================] - 403s 10s/step - loss: 0.1728 - accuracy: 0.6500 - val_loss: 0.2029 - val_accuracy: 0.6479 - lr: 1.0000e-04
# Epoch 8/175
# 40/40 [==============================] - ETA: 0s - loss: 0.1702 - accuracy: 0.6750
# Epoch 00008: val_loss did not improve from 0.20289
# 40/40 [==============================] - 394s 10s/step - loss: 0.1702 - accuracy: 0.6750 - val_loss: 0.2049 - val_accuracy: 0.6479 - lr: 1.0000e-04
# Epoch 9/175
# 40/40 [==============================] - ETA: 0s - loss: 0.1685 - accuracy: 0.7250
# Epoch 00009: val_loss did not improve from 0.20289
# 40/40 [==============================] - 394s 10s/step - loss: 0.1685 - accuracy: 0.7250 - val_loss: 0.2109 - val_accuracy: 0.6446 - lr: 1.0000e-04
# Epoch 10/175
# 40/40 [==============================] - ETA: 0s - loss: 0.1730 - accuracy: 0.7000
# Epoch 00010: val_loss did not improve from 0.20289
# 40/40 [==============================] - 394s 10s/step - loss: 0.1730 - accuracy: 0.7000 - val_loss: 0.2066 - val_accuracy: 0.6521 - lr: 1.0000e-04
# Epoch 11/175
# 40/40 [==============================] - ETA: 0s - loss: 0.1704 - accuracy: 0.7250
# Epoch 00011: val_loss improved from 0.20289 to 0.19971, saving model to ..\scripts\models_h5\siamese_network2c-t2_10notebook.h5
# 40/40 [==============================] - 394s 10s/step - loss: 0.1704 - accuracy: 0.7250 - val_loss: 0.1997 - val_accuracy: 0.6679 - lr: 1.0000e-04
# Epoch 12/175
# 40/40 [==============================] - ETA: 0s - loss: 0.1713 - accuracy: 0.6750
# Epoch 00012: val_loss improved from 0.19971 to 0.19782, saving model to ..\scripts\models_h5\siamese_network2c-t2_10notebook.h5
# 40/40 [==============================] - 396s 10s/step - loss: 0.1713 - accuracy: 0.6750 - val_loss: 0.1978 - val_accuracy: 0.6762 - lr: 1.0000e-04
# Epoch 13/175
# 40/40 [==============================] - ETA: 0s - loss: 0.1671 - accuracy: 0.7250
# Epoch 00013: val_loss did not improve from 0.19782
# 40/40 [==============================] - 397s 10s/step - loss: 0.1671 - accuracy: 0.7250 - val_loss: 0.2009 - val_accuracy: 0.6712 - lr: 1.0000e-04
# Epoch 14/175
# 40/40 [==============================] - ETA: 0s - loss: 0.1671 - accuracy: 0.7250
# Epoch 00014: val_loss did not improve from 0.19782
# 40/40 [==============================] - 393s 10s/step - loss: 0.1671 - accuracy: 0.7250 - val_loss: 0.1992 - val_accuracy: 0.6762 - lr: 1.0000e-04
# Epoch 15/175
# 40/40 [==============================] - ETA: 0s - loss: 0.1673 - accuracy: 0.7500
# Epoch 00015: val_loss did not improve from 0.19782
# 40/40 [==============================] - 394s 10s/step - loss: 0.1673 - accuracy: 0.7500 - val_loss: 0.2055 - val_accuracy: 0.6679 - lr: 1.0000e-04
# Epoch 16/175
# 40/40 [==============================] - ETA: 0s - loss: 0.1665 - accuracy: 0.7250
# Epoch 00016: val_loss improved from 0.19782 to 0.19548, saving model to ..\scripts\models_h5\siamese_network2c-t2_10notebook.h5
# 40/40 [==============================] -
175
# 40/40 [==============================] - ETA: 0s - loss: 0.1542 - accuracy: 0.8250
# Epoch 00040: val_loss did not improve from 0.18610
# 40/40 [==============================] - 400s 10s/step - loss: 0.1542 - accuracy: 0.8250 - val_loss: 0.1873 - val_accuracy: 0.7500 - lr: 1.0000e-04
# Epoch 41/175
# 40/40 [==============================] - ETA: 0s - loss: 0.1543 - accuracy: 0.8250
# Epoch 00041: val_loss did not improve from 0.18610
# 40/40 [==============================] - 399s 10s/step - loss: 0.1543 - accuracy: 0.8250 - val_loss: 0.1891 - val_accuracy: 0.7454 - lr: 1.0000e-04
# Epoch 42/175
# 40/40 [==============================] - ETA: 0s - loss: 0.1555 - accuracy: 0.7750
# Epoch 00042: val_loss did not improve from 0.18610
# 40/40 [==============================] - 399s 10s/step - loss: 0.1555 - accuracy: 0.7750 - val_loss: 0.1880 - val_accuracy: 0.7479 - lr: 1.0000e-04
# Epoch 43/175
# 40/40 [==============================] - ETA: 0s - loss: 0.1531 - accuracy: 0.8500
# Epoch 00043: val_loss did not improve from 0.18610
# 40/40 [==============================] - 396s 10s/step - loss: 0.1531 - accuracy: 0.8500 - val_loss: 0.1919 - val_accuracy: 0.7375 - lr: 1.0000e-04
# Epoch 44/175
# 40/40 [==============================] - ETA: 0s - loss: 0.1548 - accuracy: 0.7750
# Epoch 00044: val_loss did not improve from 0.18610
# 40/40 [==============================] - 398s 10s/step - loss: 0.1548 - accuracy: 0.7750 - val_loss: 0.1869 - val_accuracy: 0.7517 - lr: 1.0000e-04
# Epoch 45/175
# 40/40 [==============================] - ETA: 0s - loss: 0.1513 - accuracy: 0.8000
# Epoch 00045: val_loss improved from 0.18610 to 0.18601, saving model to ..\scripts\models_h5\siamese_network2c-t2_10notebook.h5
# 40/40 [==============================] - 397s 10s/step - loss: 0.1513 - accuracy: 0.8000 - val_loss: 0.1860 - val_accuracy: 0.7538 - lr: 2.0000e-05
# Epoch 46/175
# 40/40 [==============================] - ETA: 0s - loss: 0.1434 - accuracy: 0.84 - ETA: 0s - loss: 0.1512 - accuracy: 0.8250
# Epoch 00046: val_loss improved from 0.18601 to 0.18590, saving model to ..\scripts\models_h5\siamese_network2c-t2_10notebook.h5
# 40/40 [==============================] - 397s 10s/step - loss: 0.1512 - accuracy: 0.8250 - val_loss: 0.1859 - val_accuracy: 0.7538 - lr: 2.0000e-05
# Epoch 47/175
# 40/40 [==============================] - ETA: 0s - loss: 0.1513 - accuracy: 0.8500
# Epoch 00047: val_loss improved from 0.18590 to 0.18514, saving model to ..\scripts\models_h5\siamese_network2c-t2_10notebook.h5
# 40/40 [==============================] - 398s 10s/step - loss: 0.1513 - accuracy: 0.8500 - val_loss: 0.1851 - val_accuracy: 0.7563 - lr: 2.0000e-05
# Epoch 48/175
# 40/40 [==============================] - ETA: 0s - loss: 0.1510 - accuracy: 0.8500
# Epoch 00048: val_loss improved from 0.18514 to 0.18493, saving model to ..\scripts\models_h5\siamese_network2c-t2_10notebook.h5
# 40/40 [==============================] - 401s 10s/step - loss: 0.1510 - accuracy: 0.8500 - val_loss: 0.1849 - val_accuracy: 0.7571 - lr: 2.0000e-05
# Epoch 49/175
# 40/40 [==============================] - ETA: 0s - loss: 0.1508 - accuracy: 0.8500
# Epoch 00049: val_loss did not improve from 0.18493
# 40/40 [==============================] - 400s 10s/step - loss: 0.1508 - accuracy: 0.8500 - val_loss: 0.1850 - val_accuracy: 0.7567 - lr: 2.0000e-05
# Epoch 50/175
# 40/40 [==============================] - ETA: 0s - loss: 0.1508 - accuracy: 0.8500
# Epoch 00050: val_loss did not improve from 0.18493
# 40/40 [==============================] - 397s 10s/step - loss: 0.1508 - accuracy: 0.8500 - val_loss: 0.1851 - val_accuracy: 0.7563 - lr: 2.0000e-05
# Epoch 51/175
# 40/40 [==============================] - ETA: 0s - loss: 0.1508 - accuracy: 0.8500
# Epoch 00051: val_loss did not improve from 0.18493
# 40/40 [==============================] - 395s 10s/step - loss: 0.1508 - accuracy: 0.8500 - val_loss: 0.1857 - val_accuracy: 0.7550 - lr: 2.0000e-05
# Epoch 52/175
# 40/40 [==============================] - ETA: 0s - loss: 0.
175
# 40/40 [==============================] - ETA: 0s - loss: 0.1500 - accuracy: 0.8500
# Epoch 00064: val_loss did not improve from 0.18446
# 40/40 [==============================] - 398s 10s/step - loss: 0.1500 - accuracy: 0.8500 - val_loss: 0.1845 - val_accuracy: 0.7588 - lr: 1.0000e-05
# Epoch 65/175
# 40/40 [==============================] - ETA: 0s - loss: 0.1499 - accuracy: 0.8500
# Epoch 00065: val_loss did not improve from 0.18446
# 40/40 [==============================] - 397s 10s/step - loss: 0.1499 - accuracy: 0.8500 - val_loss: 0.1848 - val_accuracy: 0.7575 - lr: 1.0000e-05
# Epoch 66/175
# 40/40 [==============================] - ETA: 0s - loss: 0.1499 - accuracy: 0.8500
# Epoch 00066: val_loss did not improve from 0.18446
# 40/40 [==============================] - 400s 10s/step - loss: 0.1499 - accuracy: 0.8500 - val_loss: 0.1846 - val_accuracy: 0.7588 - lr: 1.0000e-05
# Epoch 67/175
# 40/40 [==============================] - ETA: 0s - loss: 0.1498 - accuracy: 0.8500
# Epoch 00067: val_loss did not improve from 0.18446
# 40/40 [==============================] - 401s 10s/step - loss: 0.1498 - accuracy: 0.8500 - val_loss: 0.1846 - val_accuracy: 0.7579 - lr: 1.0000e-05
# Epoch 68/175
# 40/40 [==============================] - ETA: 0s - loss: 0.1502 - accuracy: 0.8500
# Epoch 00068: val_loss did not improve from 0.18446
# 40/40 [==============================] - 401s 10s/step - loss: 0.1502 - accuracy: 0.8500 - val_loss: 0.1852 - val_accuracy: 0.7558 - lr: 1.0000e-05
# Epoch 69/175
# 40/40 [==============================] - ETA: 0s - loss: 0.1500 - accuracy: 0.8500
# Epoch 00069: val_loss improved from 0.18446 to 0.18420, saving model to ..\scripts\models_h5\siamese_network2c-t2_10notebook.h5
# 40/40 [==============================] - 400s 10s/step - loss: 0.1500 - accuracy: 0.8500 - val_loss: 0.1842 - val_accuracy: 0.7613 - lr: 1.0000e-05
# Epoch 70/175
# 40/40 [==============================] - ETA: 0s - loss: 0.1498 - accuracy: 0.8500
# Epoch 00070: val_loss did not improve from 0.18420
# 40/40 [==============================] - 397s 10s/step - loss: 0.1498 - accuracy: 0.8500 - val_loss: 0.1845 - val_accuracy: 0.7588 - lr: 1.0000e-05
# Epoch 71/175
# 40/40 [==============================] - ETA: 0s - loss: 0.1498 - accuracy: 0.8500
# Epoch 00071: val_loss did not improve from 0.18420
# 40/40 [==============================] - 398s 10s/step - loss: 0.1498 - accuracy: 0.8500 - val_loss: 0.1848 - val_accuracy: 0.7575 - lr: 1.0000e-05
# Epoch 72/175
# 40/40 [==============================] - ETA: 0s - loss: 0.1497 - accuracy: 0.8500
# Epoch 00072: val_loss did not improve from 0.18420
# 40/40 [==============================] - 397s 10s/step - loss: 0.1497 - accuracy: 0.8500 - val_loss: 0.1848 - val_accuracy: 0.7575 - lr: 1.0000e-05
# Epoch 73/175
# 40/40 [==============================] - ETA: 0s - loss: 0.1496 - accuracy: 0.8500
# Epoch 00073: val_loss did not improve from 0.18420
# 40/40 [==============================] - 401s 10s/step - loss: 0.1496 - accuracy: 0.8500 - val_loss: 0.1844 - val_accuracy: 0.7596 - lr: 1.0000e-05
# Epoch 74/175
# 40/40 [==============================] - ETA: 0s - loss: 0.1497 - accuracy: 0.8500
# Epoch 00074: val_loss improved from 0.18420 to 0.18401, saving model to ..\scripts\models_h5\siamese_network2c-t2_10notebook.h5
# 40/40 [==============================] - 401s 10s/step - loss: 0.1497 - accuracy: 0.8500 - val_loss: 0.1840 - val_accuracy: 0.7621 - lr: 1.0000e-05
# Epoch 75/175
# 40/40 [==============================] - ETA: 0s - loss: 0.1497 - accuracy: 0.8500
# Epoch 00075: val_loss did not improve from 0.18401
# 40/40 [==============================] - 404s 10s/step - loss: 0.1497 - accuracy: 0.8500 - val_loss: 0.1840 - val_accuracy: 0.7613 - lr: 1.0000e-05
# Epoch 76/175
# 40/40 [==============================] - ETA: 0s - loss: 0.1496 - accuracy: 0.8500
# Epoch 00076: val_loss did not improve from 0.18401
# 40/40 [==============================] - 404s 10s/step - loss: 0.1496 - accuracy: 0.8500 - val_loss: 0.1845 - val_accuracy: 0.7588 - lr: 1.0000e-05
# Epoch 77/175
# 40/40 [==============================] - ETA: 0s - loss: 0.1497 - accuracy: 0.8500
# Epoch 00077: val_loss did not improve from 0.18401
# 40/40 [==============================] - 401s 10s/step - loss: 0.1497 - accuracy: 0.8500 - val_loss: 0.1841 - val_accuracy: 0.7613 - lr: 1.0000e-05
# Epoch 78/175
# 40/40 [==============================] - ETA: 0s - loss: 0.1494 - accuracy: 0.8500
# Epoch 00078: val_loss did not improve from 0.18401
# 40/40 [==============================] - 401s 10s/step - loss: 0.1494 - accuracy: 0.8500 - val_loss: 0.1844 - val_accuracy: 0.7596 - lr: 1.0000e-05
# Epoch 79/175
# 40/40 [==============================] - ETA: 0s - loss: 0.1494 - accuracy: 0.8500 E
# Epoch 00079: val_loss did not improve from 0.18401
# 40/40 [==============================] - 400s 10s/step - loss: 0.1494 - accuracy: 0.8500 - val_loss: 0.1844 - val_accuracy: 0.7596 - lr: 1.0000e-05
# Epoch 80/175
# 40/40 [==============================] - ETA: 0s - loss: 0.1494 - accuracy: 0.8500
# Epoch 00080: val_loss did not improve from 0.18401
# 40/40 [==============================] - 401s 10s/step - loss: 0.1494 - accuracy: 0.8500 - val_loss: 0.1843 - val_accuracy: 0.7600 - lr: 1.0000e-05
# Epoch 81/175
# 40/40 [==============================] - ETA: 0s - loss: 0.1493 - accuracy: 0.8500
# Epoch 00081: val_loss did not improve from 0.18401
# 40/40 [==============================] - 398s 10s/step - loss: 0.1493 - accuracy: 0.8500 - val_loss: 0.1843 - val_accuracy: 0.7600 - lr: 1.0000e-05
# Epoch 82/175
# 40/40 [==============================] - ETA: 0s - loss: 0.1492 - accuracy: 0.8500
# Epoch 00082: val_loss did not improve from 0.18401
# 40/40 [==============================] - 397s 10s/step - loss: 0.1492 - accuracy: 0.8500 - val_loss: 0.1841 - val_accuracy: 0.7613 - lr: 1.0000e-05
# Epoch 83/175
# 40/40 [==============================] - ETA: 0s - loss: 0.1493 - accuracy: 0.8500
# Epoch 00083: val_loss improved from 0.18401 to 0.18396, saving model to ..\scripts\models_h5\siamese_network2c-t2_10notebook.h5
# 40/40 [==============================] - 399s 10s/step - loss: 0.1493 - accuracy: 0.8500 - val_loss: 0.1840 - val_accuracy: 0.7621 - lr: 1.0000e-05
# Epoch 84/175
# 40/40 [==============================] - ETA: 0s - loss: 0.1495 - accuracy: 0.8500
# Epoch 00084: val_loss improved from 0.18396 to 0.18383, saving model to ..\scripts\models_h5\siamese_network2c-t2_10notebook.h5
# 40/40 [==============================] - 399s 10s/step - loss: 0.1495 - accuracy: 0.8500 - val_loss: 0.1838 - val_accuracy: 0.7629 - lr: 1.0000e-05
# Epoch 85/175
# 40/40 [==============================] - ETA: 0s - loss: 0.1493 - accuracy: 0.8500
# Epoch 00085: val_loss did not improve from 0.18383
# 40/40 [==============================] - 409s 10s/step - loss: 0.1493 - accuracy: 0.8500 - val_loss: 0.1842 - val_accuracy: 0.7608 - lr: 1.0000e-05
# Epoch 86/175
# 40/40 [==============================] - ETA: 0s - loss: 0.1492 - accuracy: 0.8500 ETA:
# Epoch 00086: val_loss did not improve from 0.18383
# 40/40 [==============================] - 397s 10s/step - loss: 0.1492 - accuracy: 0.8500 - val_loss: 0.1839 - val_accuracy: 0.7621 - lr: 1.0000e-05
# Epoch 87/175
# 40/40 [==============================] - ETA: 0s - loss: 0.
175
# 40/40 [==============================] - ETA: 0s - loss: 0.1477 - accuracy: 0.8500
# Epoch 00124: val_loss did not improve from 0.18267
# 40/40 [==============================] - 394s 10s/step - loss: 0.1477 - accuracy: 0.8500 - val_loss: 0.1829 - val_accuracy: 0.7671 - lr: 1.0000e-05
# Epoch 125/175
# 40/40 [==============================] - ETA: 0s - loss: 0.1477 - accuracy: 0.8500
# Epoch 00125: val_loss improved from 0.18267 to 0.18261, saving model to ..\scripts\models_h5\siamese_network2c-t2_10notebook.h5
# 40/40 [==============================] - 396s 10s/step - loss: 0.1477 - accuracy: 0.8500 - val_loss: 0.1826 - val_accuracy: 0.7671 - lr: 1.0000e-05
# Epoch 126/175
# 40/40 [==============================] - ETA: 0s - loss: 0.1479 - accuracy: 0.8500
# Epoch 00126: val_loss did not improve from 0.18261
# 40/40 [==============================] - 396s 10s/step - loss: 0.1479 - accuracy: 0.8500 - val_loss: 0.1828 - val_accuracy: 0.7671 - lr: 1.0000e-05
# Epoch 127/175
# 40/40 [==============================] - ETA: 0s - loss: 0.1477 - accuracy: 0.8500
# Epoch 00127: val_loss improved from 0.18261 to 0.18260, saving model to ..\scripts\models_h5\siamese_network2c-t2_10notebook.h5
# 40/40 [==============================] - 394s 10s/step - loss: 0.1477 - accuracy: 0.8500 - val_loss: 0.1826 - val_accuracy: 0.7671 - lr: 1.0000e-05
# Epoch 128/175
# 40/40 [==============================] - ETA: 0s - loss: 0.1476 - accuracy: 0.8500
# Epoch 00128: val_loss improved from 0.18260 to 0.18234, saving model to ..\scripts\models_h5\siamese_network2c-t2_10notebook.h5
# 40/40 [==============================] - 393s 10s/step - loss: 0.1476 - accuracy: 0.8500 - val_loss: 0.1823 - val_accuracy: 0.7696 - lr: 1.0000e-05
# Epoch 129/175
# 40/40 [==============================] - ETA: 0s - loss: 0.1477 - accuracy: 0.8500
# Epoch 00129: val_loss did not improve from 0.18234
# 40/40 [==============================] - 396s 10s/step - loss: 0.1477 - accuracy: 0.8500 - val_loss: 0.1825 - val_accuracy: 0.7683 - lr: 1.0000e-05
# Epoch 130/175
# 40/40 [==============================] - ETA: 0s - loss: 0.1475 - accuracy: 0.8500
# Epoch 00130: val_loss did not improve from 0.18234
# 40/40 [==============================] - 392s 10s/step - loss: 0.1475 - accuracy: 0.8500 - val_loss: 0.1825 - val_accuracy: 0.7671 - lr: 1.0000e-05
# Epoch 131/175
# 40/40 [==============================] - ETA: 0s - loss: 0.1477 - accuracy: 0.8500
# Epoch 00131: val_loss did not improve from 0.18234
# 40/40 [==============================] - 395s 10s/step - loss: 0.1477 - accuracy: 0.8500 - val_loss: 0.1826 - val_accuracy: 0.7667 - lr: 1.0000e-05
# Epoch 132/175
# 40/40 [==============================] - ETA: 0s - loss: 0.1475 - accuracy: 0.8500
# Epoch 00132: val_loss did not improve from 0.18234
# 40/40 [==============================] - 393s 10s/step - loss: 0.1475 - accuracy: 0.8500 - val_loss: 0.1825 - val_accuracy: 0.7675 - lr: 1.0000e-05
# Epoch 133/175
# 40/40 [==============================] - ETA: 0s - loss: 0.1476 - accuracy: 0.8500
# Epoch 00133: val_loss did not improve from 0.18234
# 40/40 [==============================] - 394s 10s/step - loss: 0.1476 - accuracy: 0.8500 - val_loss: 0.1826 - val_accuracy: 0.7667 - lr: 1.0000e-05
# Epoch 134/175
# 40/40 [==============================] - ETA: 0s - loss: 0.1474 - accuracy: 0.8500
# Epoch 00134: val_loss did not improve from 0.18234
# 40/40 [==============================] - 396s 10s/step - loss: 0.1474 - accuracy: 0.8500 - val_loss: 0.1828 - val_accuracy: 0.7671 - lr: 1.0000e-05
# Epoch 135/175
# 40/40 [==============================] - ETA: 0s - loss: 0.1475 - accuracy: 0.8500
# Epoch 00135: val_loss improved from 0.18234 to 0.18225, saving model to ..\scripts\models_h5\siamese_network2c-t2_10notebook.h5
# 40/40 [==============================] - 397s 10s/step - loss: 0.1475 - accuracy: 0.8500 - val_loss: 0.1822 - val_accuracy: 0.7700 - lr: 1.0000e-05
# Epoch 136/175
# 40/40 [==============================] - ETA: 0s - loss: 0.1474 - accuracy: 0.8500
# Epoch 00136: val_loss did not improve from 0.18225
# 40/40 [==============================] - 396s 10s/step - loss: 0.1474 - accuracy: 0.8500 - val_loss: 0.1823 - val_accuracy: 0.7696 - lr: 1.0000e-05
# Epoch 137/175
# 40/40 [==============================] - ETA: 0s - loss: 0.1478 - accuracy: 0.8500
# Epoch 00137: val_loss did not improve from 0.18225
# 40/40 [==============================] - 392s 10s/step - loss: 0.1478 - accuracy: 0.8500 - val_loss: 0.1829 - val_accuracy: 0.7675 - lr: 1.0000e-05
# Epoch 138/175
# 40/40 [==============================] - ETA: 0s - loss: 0.1477 - accuracy: 0.8500
# Epoch 00138: val_loss did not improve from 0.18225
# 40/40 [==============================] - 392s 10s/step - loss: 0.1477 - accuracy: 0.8500 - val_loss: 0.1824 - val_accuracy: 0.7683 - lr: 1.0000e-05
# Epoch 00138: early stopping

# %%
results = siamese.evaluate([x_test_1, x_test_2], labels_test)
print("test loss, test acc:", results)
# Out:
# 75/75 [==============================] - 280s 4s/step - loss: 0.1357 - accuracy: 0.9296
# test loss, test acc: [0.13567844033241272, 0.9295833110809326]

# %%
Y_pred = siamese.predict([x_test_1, x_test_2]).squeeze()
# 返回的是TRUE或FALSE,没有标签数据怎么知道他被分到哪儿个类中？
y_pred = Y_pred > 0.5
# x1,和x2是否匹配：匹配1，不匹配0
y_test = labels_test
print("\nEvaluate on validation data")
Accuracy=accuracy_score(y_test, y_pred)
Precision=precision_score(y_test, y_pred, average='weighted')
Recall=recall_score(y_test, y_pred, average='weighted')
ROC_AUC=roc_auc_score(y_test, y_pred, average='weighted')
F1=f1_score(y_test, y_pred, average='weighted')
print("Accuracy:", Accuracy)
print("Precision:", Precision)
print("Recall:", Recall)
print("ROC AUC:", ROC_AUC)
print("F1:",F1 )
# Out:
# Evaluate on validation data
# Accuracy: 0.9295833333333333
# Precision: 0.9378616552529596
# Recall: 0.9295833333333333
# ROC AUC: 0.9295833333333333
# F1: 0.9292489239504429

# %%
y_pred = [1 if i else 0 for i in y_pred]
pred_labels = []

for i in range(0, len(y_pred)):
    if y_pred[i] == 1:
        pred_labels += [source_labels_test[i]]
    else:
        if source_labels_test[i] == 1:
            pred_labels += [0.0]
        else:
            pred_labels += [1.0]
a = x_test_1.tolist()
df = pd.DataFrame({"image": a, "label_{}".format(teacher_id): pred_labels})
if not os.path.exists(pre_results_path):
    os.makedirs(pre_results_path)
df.to_excel(os.path.join(pre_results_path,"{}_{}_{}.xlsx".format(epochs,teacher_id,shot)),index=False)

# %%
cm = confusion_matrix(y_test, y_pred)
cm_display = ConfusionMatrixDisplay(cm).plot()
plt.show()
tn, fp, fn, tp = cm.ravel()
specificity = tn / (tn + fp)
print("Specificity:", specificity)
data_list=[{"Accuracy":Accuracy,"Precision":Precision,"Recall":Recall,"ROC_AUC":ROC_AUC,"tn":tn,"fp":fp,"fn":fn,"tp":tp,"specificity":specificity}]
df=pd.DataFrame(data_list)

filepath=os.path.join(base_dir,r"acc_{}_{}".format(all_teachers,shot))
if not os.path.exists(filepath):
    os.mkdir(filepath)
df.to_excel(os.path.join(filepath,"{}_{}.xlsx".format(teacher_id,shot)),index=False)
tf.keras.backend.clear_session()
# Out:
# Specificity: 0.9983333333333333
