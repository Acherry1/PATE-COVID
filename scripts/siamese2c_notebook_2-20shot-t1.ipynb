# %%
# -*- coding: utf-8 -*-
import utils as utils

import tensorflow as tf
from tensorflow.keras.layers import Dense, Input, Flatten, Lambda
from tensorflow.keras.models import Model
from tensorflow.keras.optimizers import Adam
from sklearn.metrics import accuracy_score, precision_score, recall_score, roc_auc_score, f1_score

from sklearn.metrics import confusion_matrix
from sklearn.metrics import ConfusionMatrixDisplay

import numpy as np
import os

from tensorflow.keras.callbacks import EarlyStopping, ModelCheckpoint, ReduceLROnPlateau
import matplotlib.pyplot as plt
import logging

logger = tf.get_logger()
logger.setLevel(logging.ERROR)

# %%
all_teachers=2
teacher_id = 1
epochs = 175
shot = 20
SIAMESE_MODEL_NAME = '..\scripts\models_h5\siamese_network2c-t{}_{}_{}notebook.h5'.format(teacher_id,all_teachers,shot)
EMBEDDING_MODEL_NAME = 'embedding_network2w_0801.h5'
if os.path.exists(SIAMESE_MODEL_NAME):
    os.remove(SIAMESE_MODEL_NAME)

# %%
base_dir = r"F:\chest project dataset\dataset"
dataset_path = os.path.join( r"F:\chest project dataset\auto_datasets", r"auto_t{}_{}\t{}-{}".format(all_teachers,shot,teacher_id, shot))
result_file_path = os.path.join(base_dir, r"true_result_xlsx")
pre_results_path = os.path.join(base_dir, r"teacher_results_xlsx","result_{}_{}".format(all_teachers,shot))
train_image_list, train_y_list = utils.load_images(dataset_path, 'train', (100, 100))
print("The train set contains", len(train_image_list))
# Out:
# Found 40 images belonging to 2 classes.
# The train set contains 40

# %%
test_path = r"F:\chest project dataset\dataset\pretrain_2c_0727"
valid_image_list, valid_y_list = utils.load_images(test_path, 'valid', (100, 100))
print("The valid set contains", len(valid_image_list))
# Out:
# Found 1200 images belonging to 2 classes.
# The valid set contains 1200

# %%
test_image_list, test_y_list = utils.load_images(test_path, 'test', (100, 100))
print("The test set contains", len(test_image_list))
# Out:
# Found 1200 images belonging to 2 classes.
# The test set contains 1200

# %%
# make train pairs
pairs_train, labels_train, source_labels_train, true_labels_train = utils.make_pairs(train_image_list, train_y_list)

# make validation pairs
pairs_val, labels_val, source_labels_val, true_labels_val = utils.make_pairs(valid_image_list, valid_y_list)

# make validation pairs
pairs_test, labels_test, source_labels_test, true_labels_test = utils.make_pairs(test_image_list, test_y_list)
# Out:
# num_classes: 2
# num_classes: 2
# num_classes: 2

# %%
import pandas as pd

# %%
x_train_1 = pairs_train[:, 0]  # x1(如何给标签带上)
x_train_2 = pairs_train[:, 1]  # x2
print("number of pairs for train", np.shape(x_train_1)[0])

x_val_1 = pairs_val[:, 0]
x_val_2 = pairs_val[:, 1]
print("number of pairs for validation", np.shape(x_val_1)[0])

x_test_1 = pairs_test[:, 0]
x_test_2 = pairs_test[:, 1]
# print(x_test_1)
print("number of pairs for test", np.shape(x_test_1)[0])
# Out:
# number of pairs for train 80
# number of pairs for validation 2400
# number of pairs for test 2400

# %%
if not os.path.exists(result_file_path):
    os.makedirs(result_file_path)
result_xlsx=os.path.join(result_file_path,"true_labels.xlsx")
if not os.path.exists(result_xlsx):
    test_1_image_list = x_test_1.tolist()
    df = pd.DataFrame({"image": test_1_image_list, "true_label": true_labels_test})
    df.to_excel(result_xlsx, index=False)
    df = pd.read_excel(result_xlsx)
    df.drop_duplicates(inplace=True)
    df.to_excel(result_xlsx, index=False)

# %%
tf.compat.v1.reset_default_graph()

input_1 = Input((100, 100, 3))
input_2 = Input((100, 100, 3))

embedding_network = tf.keras.models.load_model(EMBEDDING_MODEL_NAME)
embedding_network.trainable = False

model = tf.keras.Sequential()
for layer in embedding_network.layers:
    model.add(layer)

model.add(Flatten(name='flat'))
model.add(Dense(5120, name='den', activation='sigmoid', kernel_regularizer='l2'))

output_1 = model(input_1)
output_2 = model(input_2)

merge_layer = Lambda(utils.manhattan_distance)([output_1, output_2])
output_layer = Dense(1, activation="sigmoid")(merge_layer)
siamese = Model(inputs=[input_1, input_2], outputs=output_layer)
siamese.summary()
# Out:
# Model: "model"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ==================================================================================================
#  input_1 (InputLayer)           [(None, 100, 100, 3  0           []
#                                 )]
#
#  input_2 (InputLayer)           [(None, 100, 100, 3  0           []
#                                 )]
#
#  sequential (Sequential)        (None, 5120)         14739266    ['input_1[0][0]',
#                                                                   'input_2[0][0]']
#
#  lambda (Lambda)                (None, 1)            0           ['sequential[0][0]',
#                                                                   'sequential[1][0]']
#
#  dense (Dense)                  (None, 1)            2           ['lambda[0][0]']
#
# ==================================================================================================
# Total params: 14,739,268
# Trainable params: 15,362
# Non-trainable params: 14,723,906
# __________________________________________________________________________________________________

# %%
reduce_lr = ReduceLROnPlateau(monitor='val_loss', factor=0.2, patience=5, min_lr=0.00001)

early_stopping = EarlyStopping(monitor='val_loss', patience=10, verbose=1, min_delta=0.0001)

checkpointer = ModelCheckpoint(filepath=SIAMESE_MODEL_NAME, verbose=1,
                               save_best_only=True)

# %%
optimizer = Adam(learning_rate=0.0001)
siamese.compile(loss=utils.loss(1), optimizer=optimizer, metrics=["accuracy"])
# siamese.compile(loss='sparse_categorical_crossentropy', optimizer=optimizer, metrics=["accuracy"])

siamese.summary()
history = siamese.fit([x_train_1, x_train_2],
                      labels_train,
                      validation_data=([x_val_1, x_val_2], labels_val),
                      batch_size=1,
                      epochs=epochs,  # 175 for contrastive 100 for cross ent
                      callbacks=[checkpointer, early_stopping, reduce_lr]
                      )
# print()
# Plot the accuracy
# utils.plt_metric(history=history.history, metric="accuracy", title="Model accuracy")

# Plot the constrastive loss
# utils.plt_metric(history=history.history, metric="loss", title="Constrastive Loss")
# Out:
# Model: "model"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ==================================================================================================
#  input_1 (InputLayer)           [(None, 100, 100, 3  0           []
#                                 )]
#
#  input_2 (InputLayer)           [(None, 100, 100, 3  0           []
#                                 )]
#
#  sequential (Sequential)        (None, 5120)         14739266    ['input_1[0][0]',
#                                                                   'input_2[0][0]']
#
#  lambda (Lambda)                (None, 1)            0           ['sequential[0][0]',
#                                                                   'sequential[1][0]']
#
#  dense (Dense)                  (None, 1)            2           ['lambda[0][0]']
#
# ==================================================================================================
# Total params: 14,739,268
# Trainable params: 15,362
# Non-trainable params: 14,723,906
# __________________________________________________________________________________________________
# Epoch 1/175
# 80/80 [==============================] - ETA: 0s - loss: 0.2198 - accuracy: 0.5750
# Epoch 00001: val_loss improved from inf to 0.23568, saving model to ..\scripts\models_h5\siamese_network2c-t1_20notebook.h5
# 80/80 [==============================] - 223s 3s/step - loss: 0.2198 - accuracy: 0.5750 - val_loss: 0.2357 - val_accuracy: 0.5733 - lr: 1.0000e-04
# Epoch 2/175
# 80/80 [==============================] - ETA: 0s - loss: 0.2022 - accuracy: 0.7000
# Epoch 00002: val_loss improved from 0.23568 to 0.22554, saving model to ..\scripts\models_h5\siamese_network2c-t1_20notebook.h5
# 80/80 [==============================] - 223s 3s/step - loss: 0.2022 - accuracy: 0.7000 - val_loss: 0.2255 - val_accuracy: 0.6129 - lr: 1.0000e-04
# Epoch 3/175
# 80/80 [==============================] - ETA: 0s - loss: 0.1901 - accuracy: 0.7000
# Epoch 00003: val_loss improved from 0.22554 to 0.21883, saving model to ..\scripts\models_h5\siamese_network2c-t1_20notebook.h5
# 80/80 [==============================] - 210s 3s/step - loss: 0.1901 - accuracy: 0.7000 - val_loss: 0.2188 - val_accuracy: 0.6371 - lr: 1.0000e-04
# Epoch 4/175
# 80/80 [==============================] - ETA: 0s - loss: 0.1821 - accuracy: 0.7250
# Epoch 00004: val_loss improved from 0.21883 to 0.21375, saving model to ..\scripts\models_h5\siamese_network2c-t1_20notebook.h5
# 80/80 [==============================] - 213s 3s/step - loss: 0.1821 - accuracy: 0.7250 - val_loss: 0.2138 - val_accuracy: 0.6538 - lr: 1.0000e-04
# Epoch 5/175
# 80/80 [==============================] - ETA: 0s - loss: 0.1765 - accuracy: 0.7375
# Epoch 00005: val_loss improved from 0.21375 to 0.21050, saving model to ..\scripts\models_h5\siamese_network2c-t1_20notebook.h5
# 80/80 [==============================] - 206s 3s/step - loss: 0.1765 - accuracy: 0.7375 - val_loss: 0.2105 - val_accuracy: 0.6633 - lr: 1.0000e-04
# Epoch 6/175
# 80/80 [==============================] - ETA: 0s - loss: 0.1722 - accuracy: 0.7500
# Epoch 00006: val_loss improved from 0.21050 to 0.20783, saving model to ..\scripts\models_h5\siamese_network2c-t1_20notebook.h5
# 80/80 [==============================] - 230s 3s/step - loss: 0.1722 - accuracy: 0.7500 - val_loss: 0.2078 - val_accuracy: 0.6721 - lr: 1.0000e-04
# Epoch 7/175
# 80/80 [==============================] - ETA: 0s - loss: 0.1689 - accuracy: 0.8500 ETA: 0s - loss: 0.166
# Epoch 00007: val_loss improved from 0.20783 to 0.20577, saving model to ..\scripts\models_h5\siamese_network2c-t1_20notebook.h5
# 80/80 [==============================] - 216s 3s/step - loss: 0.1689 - accuracy: 0.8500 - val_loss: 0.2058 - val_accuracy: 0.6812 - lr: 1.0000e-04
# Epoch 8/175
# 80/80 [==============================] - ETA: 0s - loss: 0.1667 - accuracy: 0.8750
# Epoch 00008: val_loss improved from 0.20577 to 0.20381, saving model to ..\scripts\models_h5\siamese_network2c-t1_20notebook.h5
# 80/80 [==============================] - 207s 3s/step - loss: 0.1667 - accuracy: 0.8750 - val_loss: 0.2038 - val_accuracy: 0.6896 - lr: 1.0000e-04
# Epoch 9/175
# 80/80 [==============================] - ETA: 0s - loss: 0.1643 - accuracy: 0.8750
# Epoch 00009: val_loss improved from 0.20381 to 0.20283, saving model to ..\scripts\models_h5\siamese_network2c-t1_20notebook.h5
# 80/80 [==============================] - 218s 3s/step - loss: 0.1643 - accuracy: 0.8750 - val_loss: 0.2028 - val_accuracy: 0.6950 - lr: 1.0000e-04
# Epoch 10/175
# 80/80 [==============================] - ETA: 0s - loss: 0.1625 - accuracy: 0.8875
# Epoch 00010: val_loss improved from 0.20283 to 0.20165, saving model to ..\scripts\models_h5\siamese_network2c-t1_20notebook.h5
# 80/80 [==============================] - 213s 3s/step - loss: 0.1625 - accuracy: 0.8875 - val_loss: 0.2017 - val_accuracy: 0.7029 - lr: 1.0000e-04
# Epoch 11/175
# 80/80 [==============================] - ETA: 0s - loss: 0.1606 - accuracy: 0.8875
# Epoch 00011: val_loss improved from 0.20165 to 0.20109, saving model to ..\scripts\models_h5\siamese_network2c-t1_20notebook.h5
# 80/80 [==============================] - 212s 3s/step - loss: 0.1606 - accuracy: 0.8875 - val_loss: 0.2011 - val_accuracy: 0.7075 - lr: 1.0000e-04
# Epoch 12/175
# 80/80 [==============================] - ETA: 0s - loss: 0.1592 - accuracy: 0.8875
# Epoch 00012: val_loss improved from 0.20109 to 0.19920, saving model to ..\scripts\models_h5\siamese_network2c-t1_20notebook.h5
# 80/80 [==============================] - 213s 3s/step - loss: 0.1592 - accuracy: 0.8875 - val_loss: 0.1992 - val_accuracy: 0.7150 - lr: 1.0000e-04
# Epoch 13/175
# 80/80 [==============================] - ETA: 0s - loss: 0.1580 - accuracy: 0.9000
# Epoch 00013: val_loss improved from 0.19920 to 0.19816, saving model to ..\scripts\models_h5\siamese_network2c-t1_20notebook.h5
# 80/80 [==============================] - 230s 3s/step - loss: 0.1580 - accuracy: 0.9000 - val_loss: 0.1982 - val_accuracy: 0.7217 - lr: 1.0000e-04
# Epoch 14/175
# 80/80 [==============================] - ETA: 0s - loss: 0.1564 - accuracy: 0.9125
# Epoch 00014: val_loss improved from 0.19816 to 0.19761, saving model to ..\scripts\models_h5\siamese_network2c-t1_20notebook.h5
# 80/80 [==============================] - 221s 3s/step - loss: 0.1564 - accuracy: 0.9125 - val_loss: 0.1976 - val_accuracy: 0.7279 - lr: 1.0000e-04
# Epoch 15/175
# 80/80 [==============================] - ETA: 0s - loss: 0.1552 - accuracy: 0.9125
# Epoch 00015: val_loss improved from 0.19761 to 0.19731, saving model to ..\scripts\models_h5\siamese_network2c-t1_20notebook.h5
# 80/80 [==============================] - 212s 3s/step - loss: 0.1552 - accuracy: 0.9125 - val_loss: 0.1973 - val_accuracy: 0.7308 - lr: 1.0000e-04
# Epoch 16/175
# 80/80 [==============================] - ETA: 0s - loss: 0.1540 - accuracy: 0.9125
# Epoch 00016: val_loss improved from 0.19731 to 0.19606, saving model to ..\scripts\models_h5\siamese_network2c-t1_20notebook.h5
# 80/80 [==============================] - 214s 3s/step - loss: 0.1540 - accuracy: 0.9125 - val_loss: 0.1961 - val_accuracy: 0.7337 - lr: 1.0000e-04
# Epoch 17/175
# 80/80 [==============================] - ETA: 0s - loss: 0.1529 - accuracy: 0.9125
# Epoch 00017: val_loss improved from 0.19606 to 0.19482, saving model to ..\scripts\models_h5\siamese_network2c-t1_20notebook.h5
# 80/80 [==============================] - 212s 3s/step - loss: 0.1529 - accuracy: 0.9125 - val_loss: 0.1948 - val_accuracy: 0.7400 - lr: 1.0000e-04
# Epoch 18/175
# 80/80 [==============================] - ETA: 0s - loss: 0.1518 - accuracy: 0.9125
# Epoch 00018: val_loss improved from 0.19482 to 0.19437, saving model to ..\scripts\models_h5\siamese_network2c-t1_20notebook.h5
# 80/80 [==============================] - 209s 3s/step - loss: 0.1518 - accuracy: 0.9125 - val_loss: 0.1944 - val_accuracy: 0.7421 - lr: 1.0000e-04
# Epoch 19/175
# 80/80 [==============================] - ETA: 0s - loss: 0.1507 - accuracy: 0.9125
# Epoch 00019: val_loss improved from 0.19437 to 0.19414, saving model to ..\scripts\models_h5\siamese_network2c-t1_20notebook.h5
# 80/80 [==============================] - 209s 3s/step - loss: 0.1507 - accuracy: 0.9125 - val_loss: 0.1941 - val_accuracy: 0.7437 - lr: 1.0000e-04
# Epoch 20/175
# 80/80 [==============================] - ETA: 0s - loss: 0.1497 - accuracy: 0.9125 E
# Epoch 00020: val_loss improved from 0.19414 to 0.19301, saving model to ..\scripts\models_h5\siamese_network2c-t1_20notebook.h5
# 80/80 [==============================] - 209s 3s/step - loss: 0.1497 - accuracy: 0.9125 - val_loss: 0.1930 - val_accuracy: 0.7517 - lr: 1.0000e-04
# Epoch 21/175
# 80/80 [==============================] - ETA: 0s - loss: 0.1487 - accuracy: 0.9125
# Epoch 00021: val_loss improved from 0.19301 to 0.19257, saving model to ..\scripts\models_h5\siamese_network2c-t1_20notebook.h5
# 80/80 [==============================] - 210s 3s/step - loss: 0.1487 - accuracy: 0.9125 - val_loss: 0.1926 - val_accuracy: 0.7542 - lr: 1.0000e-04
# Epoch 22/175
# 80/80 [==============================] - ETA: 0s - loss: 0.1478 - accuracy: 0.9125
# Epoch 00022: val_loss improved from 0.19257 to 0.19162, saving model to ..\scripts\models_h5\siamese_network2c-t1_20notebook.h5
# 80/80 [==============================] - 208s 3s/step - loss: 0.1478 - accuracy: 0.9125 - val_loss: 0.1916 - val_accuracy: 0.7604 - lr: 1.0000e-04
# Epoch 23/175
# 80/80 [==============================] - ETA: 0s - loss: 0.1468 - accuracy: 0.9125
# Epoch 00023: val_loss improved from 0.19162 to 0.19048, saving model to ..\scripts\models_h5\siamese_network2c-t1_20notebook.h5
# 80/80 [==============================] - 209s 3s/step - loss: 0.1468 - accuracy: 0.9125 - val_loss: 0.1905 - val_accuracy: 0.7638 - lr: 1.0000e-04
# Epoch 24/175
# 80/80 [==============================] - ETA: 0s - loss: 0.1462 - accuracy: 0.9125
# Epoch 00024: val_loss improved from 0.19048 to 0.19020, saving model to ..\scripts\models_h5\siamese_network2c-t1_20notebook.h5
# 80/80 [==============================] - 210s 3s/step - loss: 0.1462 - accuracy: 0.9125 - val_loss: 0.1902 - val_accuracy: 0.7650 - lr: 1.0000e-04
# Epoch 25/175
# 80/80 [==============================] - ETA: 0s - loss: 0.1450 - accuracy: 0.9125
# Epoch 00025: val_loss improved from 0.19020 to 0.18920, saving model to ..\scripts\models_h5\siamese_network2c-t1_20notebook.h5
# 80/80 [==============================] - 211s 3s/step - loss: 0.1450 - accuracy: 0.9125 - val_loss: 0.1892 - val_accuracy: 0.7667 - lr: 1.0000e-04
# Epoch 26/175
# 80/80 [==============================] - ETA: 0s - loss: 0.1444 - accuracy: 0.9125
# Epoch 00026: val_loss did not improve from 0.18920
# 80/80 [==============================] - 210s 3s/step - loss: 0.1444 - accuracy: 0.9125 - val_loss: 0.1896 - val_accuracy: 0.7667 - lr: 1.0000e-04
# Epoch 27/175
# 80/80 [==============================] - ETA: 0s - loss: 0.1433 - accuracy: 0.9125
# Epoch 00027: val_loss improved from 0.18920 to 0.18813, saving model to ..\scripts\models_h5\siamese_network2c-t1_20notebook.h5
# 80/80 [==============================] - 211s 3s/step - loss: 0.1433 - accuracy: 0.9125 - val_loss: 0.1881 - val_accuracy: 0.7700 - lr: 1.0000e-04
# Epoch 28/175
# 80/80 [==============================] - ETA: 0s - loss: 0.1426 - accuracy: 0.9125 ETA: 1s - loss: - ETA: 0s - loss: 0.1475 - accura
# Epoch 00028: val_loss improved from 0.18813 to 0.18764, saving model to ..\scripts\models_h5\siamese_network2c-t1_20notebook.h5
# 80/80 [==============================] - 209s 3s/step - loss: 0.1426 - accuracy: 0.9125 - val_loss: 0.1876 - val_accuracy: 0.7742 - lr: 1.0000e-04
# Epoch 29/175
# 80/80 [==============================] - ETA: 0s - loss: 0.1419 - accuracy: 0.9125
# Epoch 00029: val_loss improved from 0.18764 to 0.18721, saving model to ..\scripts\models_h5\siamese_network2c-t1_20notebook.h5
# 80/80 [==============================] - 210s 3s/step - loss: 0.1419 - accuracy: 0.9125 - val_loss: 0.1872 - val_accuracy: 0.7767 - lr: 1.0000e-04
# Epoch 30/175
# 80/80 [==============================] - ETA: 0s - loss: 0.1411 - accuracy: 0.9125
# Epoch 00030: val_loss improved from 0.18721 to 0.18608, saving model to ..\scripts\models_h5\siamese_network2c-t1_20notebook.h5
# 80/80 [==============================] - 216s 3s/step - loss: 0.1411 - accuracy: 0.9125 - val_loss: 0.1861 - val_accuracy: 0.7800 - lr: 1.0000e-04
# Epoch 31/175
# 80/80 [==============================] - ETA: 0s - loss: 0.1402 - accuracy: 0.9375
# Epoch 00031: val_loss did not improve from 0.18608
# 80/80 [==============================] - 212s 3s/step - loss: 0.1402 - accuracy: 0.9375 - val_loss: 0.1869 - val_accuracy: 0.7783 - lr: 1.0000e-04
# Epoch 32/175
# 80/80 [==============================] - ETA: 0s - loss: 0.1395 - accuracy: 0.9250
# Epoch 00032: val_loss improved from 0.18608 to 0.18572, saving model to ..\scripts\models_h5\siamese_network2c-t1_20notebook.h5
# 80/80 [==============================] - 210s 3s/step - loss: 0.1395 - accuracy: 0.9250 - val_loss: 0.1857 - val_accuracy: 0.7800 - lr: 1.0000e-04
# Epoch 33/175
# 80/80 [==============================] - ETA: 0s - loss: 0.1387 - accuracy: 0.9625
# Epoch 00033: val_loss improved from 0.18572 to 0.18544, saving model to ..\scripts\models_h5\siamese_network2c-t1_20notebook.h5
# 80/80 [==============================] - 209s 3s/step - loss: 0.1387 - accuracy: 0.9625 - val_loss: 0.1854 - val_accuracy: 0.7812 - lr: 1.0000e-04
# Epoch 34/175
# 80/80 [==============================] - ETA: 0s - loss: 0.1382 - accuracy: 0.9500
# Epoch 00034: val_loss improved from 0.18544 to 0.18384, saving model to ..\scripts\models_h5\siamese_network2c-t1_20notebook.h5
# 80/80 [==============================] - 209s 3s/step - loss: 0.1382 - accuracy: 0.9500 - val_loss: 0.1838 - val_accuracy: 0.7879 - lr: 1.0000e-04
# Epoch 35/175
# 80/80 [==============================] - ETA: 0s - loss: 0.1373 - accuracy: 0.9625
# Epoch 00035: val_loss did not improve from 0.18384
# 80/80 [==============================] - 208s 3s/step - loss: 0.1373 - accuracy: 0.9625 - val_loss: 0.1839 - val_accuracy: 0.7875 - lr: 1.0000e-04
# Epoch 36/175
# 80/80 [==============================] - ETA: 0s - loss: 0.1366 - accuracy: 0.9625
# Epoch 00036: val_loss did not improve from 0.18384
# 80/80 [==============================] - 208s 3s/step - loss: 0.1366 - accuracy: 0.9625 - val_loss: 0.1841 - val_accuracy: 0.7862 - lr: 1.0000e-04
# Epoch 37/175
# 80/80 [==============================] - ETA: 0s - loss: 0.1360 - accuracy: 0.9625
# Epoch 00037: val_loss improved from 0.18384 to 0.18284, saving model to ..\scripts\models_h5\siamese_network2c-t1_20notebook.h5
# 80/80 [==============================] - 209s 3s/step - loss: 0.1360 - accuracy: 0.9625 - val_loss: 0.1828 - val_accuracy: 0.7900 - lr: 1.0000e-04
# Epoch 38/175
# 80/80 [==============================] - ETA: 0s - loss: 0.1352 - accuracy: 0.9625
# Epoch 00038: val_loss improved from 0.18284 to 0.18170, saving model to ..\scripts\models_h5\siamese_network2c-t1_20notebook.h5
# 80/80 [==============================] - 209s 3s/step - loss: 0.1352 - accuracy: 0.9625 - val_loss: 0.1817 - val_accuracy: 0.7958 - lr: 1.0000e-04
# Epoch 39/175
# 80/80 [==============================] - ETA: 0s - loss: 0.1344 - accuracy: 0.9625
# Epoch 00039: val_loss did not improve from 0.18170
# 80/80 [==============================] - 210s 3s/step - loss: 0.1344 - accuracy: 0.9625 - val_loss: 0.1828 - val_accuracy: 0.7904 - lr: 1.0000e-04
# Epoch 40/175
# 80/80 [==============================] - ETA: 0s - loss: 0.1338 - accuracy: 0.9625
# Epoch 00040: val_loss did not improve from 0.18170
# 80/80 [==============================] - 211s 3s/step - loss: 0.1338 - accuracy: 0.9625 - val_loss: 0.1817 - val_accuracy: 0.7950 - lr: 1.0000e-04
# Epoch 41/175
# 80/80 [==============================] - ETA: 0s - loss: 0.1332 - accuracy: 0.9625
# Epoch 00041: val_loss improved from 0.18170 to 0.18162, saving model to ..\scripts\models_h5\siamese_network2c-t1_20notebook.h5
# 80/80 [==============================] - 210s 3s/step - loss: 0.1332 - accuracy: 0.9625 - val_loss: 0.1816 - val_accuracy: 0.7967 - lr: 1.0000e-04
# Epoch 42/175
# 80/80 [==============================] - ETA: 0s - loss: 0.1324 - accuracy: 0.9625 ETA: 0s - loss: 0.1300 - accuracy
# Epoch 00042: val_loss improved from 0.18162 to 0.18079, saving model to ..\scripts\models_h5\siamese_network2c-t1_20notebook.h5
# 80/80 [==============================] - 210s 3s/step - loss: 0.1324 - accuracy: 0.9625 - val_loss: 0.1808 - val_accuracy: 0.7983 - lr: 1.0000e-04
# Epoch 43/175
# 80/80 [==============================] - ETA: 0s - loss: 0.1317 - accuracy: 0.9625
# Epoch 00043: val_loss improved from 0.18079 to 0.17946, saving model to ..\scripts\models_h5\siamese_network2c-t1_20notebook.h5
# 80/80 [==============================] - 211s 3s/step - loss: 0.1317 - accuracy: 0.9625 - val_loss: 0.1795 - val_accuracy: 0.8008 - lr: 1.0000e-04
# Epoch 44/175
# 80/80 [==============================] - ETA: 0s - loss: 0.1312 - accuracy: 0.9625
# Epoch 00044: val_loss did not improve from 0.17946
# 80/80 [==============================] - 209s 3s/step - loss: 0.1312 - accuracy: 0.9625 - val_loss: 0.1795 - val_accuracy: 0.8008 - lr: 1.0000e-04
# Epoch 45/175
# 80/80 [==============================] - ETA: 0s - loss: 0.1305 - accuracy: 0.9625
# Epoch 00045: val_loss improved from 0.17946 to 0.17932, saving model to ..\scripts\models_h5\siamese_network2c-t1_20notebook.h5
# 80/80 [==============================] - 210s 3s/step - loss: 0.1305 - accuracy: 0.9625 - val_loss: 0.1793 - val_accuracy: 0.8017 - lr: 1.0000e-04
# Epoch 46/175
# 80/80 [==============================] - ETA: 0s - loss: 0.1298 - accuracy: 0.9625
# Epoch 00046: val_loss improved from 0.17932 to 0.17824, saving model to ..\scripts\models_h5\siamese_network2c-t1_20notebook.h5
# 80/80 [==============================] - 209s 3s/step - loss: 0.1298 - accuracy: 0.9625 - val_loss: 0.1782 - val_accuracy: 0.8062 - lr: 1.0000e-04
# Epoch 47/175
# 80/80 [==============================] - ETA: 0s - loss: 0.1290 - accuracy: 0.9625
# Epoch 00047: val_loss improved from 0.17824 to 0.17789, saving model to ..\scripts\models_h5\siamese_network2c-t1_20notebook.h5
# 80/80 [==============================] - 208s 3s/step - loss: 0.1290 - accuracy: 0.9625 - val_loss: 0.1779 - val_accuracy: 0.8067 - lr: 1.0000e-04
# Epoch 48/175
# 80/80 [==============================] - ETA: 0s - loss: 0.1287 - accuracy: 0.9625
# Epoch 00048: val_loss did not improve from 0.17789
# 80/80 [==============================] - 208s 3s/step - loss: 0.1287 - accuracy: 0.9625 - val_loss: 0.1781 - val_accuracy: 0.8062 - lr: 1.0000e-04
# Epoch 49/175
# 80/80 [==============================] - ETA: 0s - loss: 0.1280 - accuracy: 0.9625
# Epoch 00049: val_loss improved from 0.17789 to 0.17739, saving model to ..\scripts\models_h5\siamese_network2c-t1_20notebook.h5
# 80/80 [==============================] - 209s 3s/step - loss: 0.1280 - accuracy: 0.9625 - val_loss: 0.1774 - val_accuracy: 0.8067 - lr: 1.0000e-04
# Epoch 50/175
# 80/80 [==============================] - ETA: 0s - loss: 0.1273 - accuracy: 0.9625
# Epoch 00050: val_loss improved from 0.17739 to 0.17722, saving model to ..\scripts\models_h5\siamese_network2c-t1_20notebook.h5
# 80/80 [==============================] - 208s 3s/step - loss: 0.1273 - accuracy: 0.9625 - val_loss: 0.1772 - val_accuracy: 0.8067 - lr: 1.0000e-04
# Epoch 51/175
# 80/80 [==============================] - ETA: 0s - loss: 0.1269 - accuracy: 0.9625
# Epoch 00051: val_loss improved from 0.17722 to 0.17649, saving model to ..\scripts\models_h5\siamese_network2c-t1_20notebook.h5
# 80/80 [==============================] - 207s 3s/step - loss: 0.1269 - accuracy: 0.9625 - val_loss: 0.1765 - val_accuracy: 0.8104 - lr: 1.0000e-04
# Epoch 52/175
# 80/80 [==============================] - ETA: 0s - loss: 0.1260 - accuracy: 0.9625
# Epoch 00052: val_loss improved from 0.17649 to 0.17633, saving model to ..\scripts\models_h5\siamese_network2c-t1_20notebook.h5
# 80/80 [==============================] - 210s 3s/step - loss: 0.1260 - accuracy: 0.9625 - val_loss: 0.1763 - val_accuracy: 0.8112 - lr: 1.0000e-04
# Epoch 53/175
# 80/80 [==============================] - ETA: 0s - loss: 0.1256 - accuracy: 0.9625
# Epoch 00053: val_loss improved from 0.17633 to 0.17579, saving model to ..\scripts\models_h5\siamese_network2c-t1_20notebook.h5
# 80/80 [==============================] - 210s 3s/step - loss: 0.1256 - accuracy: 0.9625 - val_loss: 0.1758 - val_accuracy: 0.8117 - lr: 1.0000e-04
# Epoch 54/175
# 80/80 [==============================] - ETA: 0s - loss: 0.1253 - accuracy: 0.9625 ETA: 1s - loss: 0.1130 - accuracy: 0.96 - ETA: 1s -
# Epoch 00054: val_loss did not improve from 0.17579
# 80/80 [==============================] - 208s 3s/step - loss: 0.1253 - accuracy: 0.9625 - val_loss: 0.1769 - val_accuracy: 0.8096 - lr: 1.0000e-04
# Epoch 55/175
# 80/80 [==============================] - ETA: 0s - loss: 0.1243 - accuracy: 0.9625
# Epoch 00055: val_loss improved from 0.17579 to 0.17485, saving model to ..\scripts\models_h5\siamese_network2c-t1_20notebook.h5
# 80/80 [==============================] - 207s 3s/step - loss: 0.1243 - accuracy: 0.9625 - val_loss: 0.1749 - val_accuracy: 0.8117 - lr: 1.0000e-04
# Epoch 56/175
# 80/80 [==============================] - ETA: 0s - loss: 0.1237 - accuracy: 0.9625
# Epoch 00056: val_loss improved from 0.17485 to 0.17404, saving model to ..\scripts\models_h5\siamese_network2c-t1_20notebook.h5
# 80/80 [==============================] - 208s 3s/step - loss: 0.1237 - accuracy: 0.9625 - val_loss: 0.1740 - val_accuracy: 0.8121 - lr: 1.0000e-04
# Epoch 57/175
# 80/80 [==============================] - ETA: 0s - loss: 0.1229 - accuracy: 0.9625
# Epoch 00057: val_loss improved from 0.17404 to 0.17382, saving model to ..\scripts\models_h5\siamese_network2c-t1_20notebook.h5
# 80/80 [==============================] - 207s 3s/step - loss: 0.1229 - accuracy: 0.9625 - val_loss: 0.1738 - val_accuracy: 0.8129 - lr: 1.0000e-04
# Epoch 58/175
# 80/80 [==============================] - ETA: 0s - loss: 0.1224 - accuracy: 0.9625
# Epoch 00058: val_loss improved from 0.17382 to 0.17279, saving model to ..\scripts\models_h5\siamese_network2c-t1_20notebook.h5
# 80/80 [==============================] - 207s 3s/step - loss: 0.1224 - accuracy: 0.9625 - val_loss: 0.1728 - val_accuracy: 0.8167 - lr: 1.0000e-04
# Epoch 59/175
# 80/80 [==============================] - ETA: 0s - loss: 0.1218 - accuracy: 0.9625
# Epoch 00059: val_loss improved from 0.17279 to 0.17266, saving model to ..\scripts\models_h5\siamese_network2c-t1_20notebook.h5
# 80/80 [==============================] - 206s 3s/step - loss: 0.1218 - accuracy: 0.9625 - val_loss: 0.1727 - val_accuracy: 0.8171 - lr: 1.0000e-04
# Epoch 60/175
# 80/80 [==============================] - ETA: 0s - loss: 0.1215 - accuracy: 0.9625
# Epoch 00060: val_loss did not improve from 0.17266
# 80/80 [==============================] - 206s 3s/step - loss: 0.1215 - accuracy: 0.9625 - val_loss: 0.1731 - val_accuracy: 0.8158 - lr: 1.0000e-04
# Epoch 61/175
# 80/80 [==============================] - ETA: 0s - loss: 0.1207 - accuracy: 0.9625
# Epoch 00061: val_loss improved from 0.17266 to 0.17202, saving model to ..\scripts\models_h5\siamese_network2c-t1_20notebook.h5
# 80/80 [==============================] - 205s 3s/step - loss: 0.1207 - accuracy: 0.9625 - val_loss: 0.1720 - val_accuracy: 0.8188 - lr: 1.0000e-04
# Epoch 62/175
# 80/80 [==============================] - ETA: 0s - loss: 0.1202 - accuracy: 0.9625
# Epoch 00062: val_loss improved from 0.17202 to 0.17076, saving model to ..\scripts\models_h5\siamese_network2c-t1_20notebook.h5
# 80/80 [==============================] - 206s 3s/step - loss: 0.1202 - accuracy: 0.9625 - val_loss: 0.1708 - val_accuracy: 0.8229 - lr: 1.0000e-04
# Epoch 63/175
# 80/80 [==============================] - ETA: 0s - loss: 0.1194 - accuracy: 0.9625
# Epoch 00063: val_loss did not improve from 0.17076
# 80/80 [==============================] - 206s 3s/step - loss: 0.1194 - accuracy: 0.9625 - val_loss: 0.1715 - val_accuracy: 0.8200 - lr: 1.0000e-04
# Epoch 64/175
# 80/80 [==============================] - ETA: 0s - loss: 0.1190 - accuracy: 0.9625
# Epoch 00064: val_loss improved from 0.17076 to 0.17001, saving model to ..\scripts\models_h5\siamese_network2c-t1_20notebook.h5
# 80/80 [==============================] - 206s 3s/step - loss: 0.1190 - accuracy: 0.9625 - val_loss: 0.1700 - val_accuracy: 0.8246 - lr: 1.0000e-04
# Epoch 65/175
# 80/80 [==============================] - ETA: 0s - loss: 0.1185 - accuracy: 0.9625
# Epoch 00065: val_loss did not improve from 0.17001
# 80/80 [==============================] - 206s 3s/step - loss: 0.1185 - accuracy: 0.9625 - val_loss: 0.1704 - val_accuracy: 0.8225 - lr: 1.0000e-04
# Epoch 66/175
# 80/80 [==============================] - ETA: 0s - loss: 0.1180 - accuracy: 0.9625
# Epoch 00066: val_loss did not improve from 0.17001
# 80/80 [==============================] - 205s 3s/step - loss: 0.1180 - accuracy: 0.9625 - val_loss: 0.1702 - val_accuracy: 0.8233 - lr: 1.0000e-04
# Epoch 67/175
# 80/80 [==============================] - ETA: 0s - loss: 0.1174 - accuracy: 0.9625
# Epoch 00067: val_loss improved from 0.17001 to 0.16943, saving model to ..\scripts\models_h5\siamese_network2c-t1_20notebook.h5
# 80/80 [==============================] - 206s 3s/step - loss: 0.1174 - accuracy: 0.9625 - val_loss: 0.1694 - val_accuracy: 0.8246 - lr: 1.0000e-04
# Epoch 68/175
# 80/80 [==============================] - ETA: 0s - loss: 0.1171 - accuracy: 0.9625
# Epoch 00068: val_loss improved from 0.16943 to 0.16866, saving model to ..\scripts\models_h5\siamese_network2c-t1_20notebook.h5
# 80/80 [==============================] - 206s 3s/step - loss: 0.1171 - accuracy: 0.9625 - val_loss: 0.1687 - val_accuracy: 0.8258 - lr: 1.0000e-04
# Epoch 69/175
# 80/80 [==============================] - ETA: 0s - loss: 0.1162 - accuracy: 0.9625
# Epoch 00069: val_loss did not improve from 0.16866
# 80/80 [==============================] - 206s 3s/step - loss: 0.1162 - accuracy: 0.9625 - val_loss: 0.1691 - val_accuracy: 0.8250 - lr: 1.0000e-04
# Epoch 70/175
# 80/80 [==============================] - ETA: 0s - loss: 0.1158 - accuracy: 0.9625
# Epoch 00070: val_loss improved from 0.16866 to 0.16852, saving model to ..\scripts\models_h5\siamese_network2c-t1_20notebook.h5
# 80/80 [==============================] - 205s 3s/step - loss: 0.1158 - accuracy: 0.9625 - val_loss: 0.1685 - val_accuracy: 0.8250 - lr: 1.0000e-04
# Epoch 71/175
# 80/80 [==============================] - ETA: 0s - loss: 0.1154 - accuracy: 0.9625
# Epoch 00071: val_loss improved from 0.16852 to 0.16826, saving model to ..\scripts\models_h5\siamese_network2c-t1_20notebook.h5
# 80/80 [==============================] - 207s 3s/step - loss: 0.1154 - accuracy: 0.9625 - val_loss: 0.1683 - val_accuracy: 0.8258 - lr: 1.0000e-04
# Epoch 72/175
# 80/80 [==============================] - ETA: 0s - loss: 0.1150 - accuracy: 0.9625
# Epoch 00072: val_loss improved from 0.16826 to 0.16796, saving model to ..\scripts\models_h5\siamese_network2c-t1_20notebook.h5
# 80/80 [==============================] - 206s 3s/step - loss: 0.1150 - accuracy: 0.9625 - val_loss: 0.1680 - val_accuracy: 0.8263 - lr: 1.0000e-04
# Epoch 73/175
# 80/80 [==============================] - ETA: 0s - loss: 0.1140 - accuracy: 0.9625 ETA: 1s - los
# Epoch 00073: val_loss improved from 0.16796 to 0.16668, saving model to ..\scripts\models_h5\siamese_network2c-t1_20notebook.h5
# 80/80 [==============================] - 208s 3s/step - loss: 0.1140 - accuracy: 0.9625 - val_loss: 0.1667 - val_accuracy: 0.8283 - lr: 1.0000e-04
# Epoch 74/175
# 80/80 [==============================] - ETA: 0s - loss: 0.1139 - accuracy: 0.9625
# Epoch 00074: val_loss improved from 0.16668 to 0.16616, saving model to ..\scripts\models_h5\siamese_network2c-t1_20notebook.h5
# 80/80 [==============================] - 206s 3s/step - loss: 0.1139 - accuracy: 0.9625 - val_loss: 0.1662 - val_accuracy: 0.8283 - lr: 1.0000e-04
# Epoch 75/175
# 80/80 [==============================] - ETA: 0s - loss: 0.1132 - accuracy: 0.9625
# Epoch 00075: val_loss improved from 0.16616 to 0.16538, saving model to ..\scripts\models_h5\siamese_network2c-t1_20notebook.h5
# 80/80 [==============================] - 206s 3s/step - loss: 0.1132 - accuracy: 0.9625 - val_loss: 0.1654 - val_accuracy: 0.8308 - lr: 1.0000e-04
# Epoch 76/175
# 80/80 [==============================] - ETA: 0s - loss: 0.1124 - accuracy: 0.9625
# Epoch 00076: val_loss improved from 0.16538 to 0.16505, saving model to ..\scripts\models_h5\siamese_network2c-t1_20notebook.h5
# 80/80 [==============================] - 207s 3s/step - loss: 0.1124 - accuracy: 0.9625 - val_loss: 0.1651 - val_accuracy: 0.8308 - lr: 1.0000e-04
# Epoch 77/175
# 80/80 [==============================] - ETA: 0s - loss: 0.1121 - accuracy: 0.9625
# Epoch 00077: val_loss improved from 0.16505 to 0.16423, saving model to ..\scripts\models_h5\siamese_network2c-t1_20notebook.h5
# 80/80 [==============================] - 206s 3s/step - loss: 0.1121 - accuracy: 0.9625 - val_loss: 0.1642 - val_accuracy: 0.8325 - lr: 1.0000e-04
# Epoch 78/175
# 80/80 [==============================] - ETA: 0s - loss: 0.1116 - accuracy: 0.9625
# Epoch 00078: val_loss improved from 0.16423 to 0.16397, saving model to ..\scripts\models_h5\siamese_network2c-t1_20notebook.h5
# 80/80 [==============================] - 207s 3s/step - loss: 0.1116 - accuracy: 0.9625 - val_loss: 0.1640 - val_accuracy: 0.8329 - lr: 1.0000e-04
# Epoch 79/175
# 80/80 [==============================] - ETA: 0s - loss: 0.1109 - accuracy: 0.9625
# Epoch 00079: val_loss did not improve from 0.16397
# 80/80 [==============================] - 206s 3s/step - loss: 0.1109 - accuracy: 0.9625 - val_loss: 0.1650 - val_accuracy: 0.8296 - lr: 1.0000e-04
# Epoch 80/175
# 80/80 [==============================] - ETA: 0s - loss: 0.1103 - accuracy: 0.9625 ETA: 0s - loss: 0.1
# Epoch 00080: val_loss did not improve from 0.16397
# 80/80 [==============================] - 206s 3s/step - loss: 0.1103 - accuracy: 0.9625 - val_loss: 0.1652 - val_accuracy: 0.8283 - lr: 1.0000e-04
# Epoch 81/175
# 80/80 [==============================] - ETA: 0s - loss: 0.1100 - accuracy: 0.9625
# Epoch 00081: val_loss did not improve from 0.16397
# 80/80 [==============================] - 205s 3s/step - loss: 0.1100 - accuracy: 0.9625 - val_loss: 0.1640 - val_accuracy: 0.8313 - lr: 1.0000e-04
# Epoch 82/175
# 80/80 [==============================] - ETA: 0s - loss: 0.1093 - accuracy: 0.9625
# Epoch 00082: val_loss did not improve from 0.16397
# 80/80 [==============================] - 207s 3s/step - loss: 0.1093 - accuracy: 0.9625 - val_loss: 0.1641 - val_accuracy: 0.8308 - lr: 1.0000e-04
# Epoch 83/175
# 80/80 [==============================] - ETA: 0s - loss: 0.1088 - accuracy: 0.9625
# Epoch 00083: val_loss improved from 0.16397 to 0.16307, saving model to ..\scripts\models_h5\siamese_network2c-t1_20notebook.h5
# 80/80 [==============================] - 207s 3s/step - loss: 0.1088 - accuracy: 0.9625 - val_loss: 0.1631 - val_accuracy: 0.8325 - lr: 1.0000e-04
# Epoch 84/175
# 80/80 [==============================] - ETA: 0s - loss: 0.1084 - accuracy: 0.9625
# Epoch 00084: val_loss improved from 0.16307 to 0.16255, saving model to ..\scripts\models_h5\siamese_network2c-t1_20notebook.h5
# 80/80 [==============================] - 207s 3s/step - loss: 0.1084 - accuracy: 0.9625 - val_loss: 0.1625 - val_accuracy: 0.8329 - lr: 1.0000e-04
# Epoch 85/175
# 80/80 [==============================] - ETA: 0s - loss: 0.1078 - accuracy: 0.9625
# Epoch 00085: val_loss did not improve from 0.16255
# 80/80 [==============================] - 207s 3s/step - loss: 0.1078 - accuracy: 0.9625 - val_loss: 0.1629 - val_accuracy: 0.8325 - lr: 1.0000e-04
# Epoch 86/175
# 80/80 [==============================] - ETA: 0s - loss: 0.1074 - accuracy: 0.9625
# Epoch 00086: val_loss improved from 0.16255 to 0.16139, saving model to ..\scripts\models_h5\siamese_network2c-t1_20notebook.h5
# 80/80 [==============================] - 207s 3s/step - loss: 0.1074 - accuracy: 0.9625 - val_loss: 0.1614 - val_accuracy: 0.8338 - lr: 1.0000e-04
# Epoch 87/175
# 80/80 [==============================] - ETA: 0s - loss: 0.1067 - accuracy: 0.9625
# Epoch 00087: val_loss did not improve from 0.16139
# 80/80 [==============================] - 209s 3s/step - loss: 0.1067 - accuracy: 0.9625 - val_loss: 0.1619 - val_accuracy: 0.8333 - lr: 1.0000e-04
# Epoch 88/175
# 80/80 [==============================] - ETA: 0s - loss: 0.1067 - accuracy: 0.9625
# Epoch 00088: val_loss improved from 0.16139 to 0.16018, saving model to ..\scripts\models_h5\siamese_network2c-t1_20notebook.h5
# 80/80 [==============================] - 207s 3s/step - loss: 0.1067 - accuracy: 0.9625 - val_loss: 0.1602 - val_accuracy: 0.8358 - lr: 1.0000e-04
# Epoch 89/175
# 80/80 [==============================] - ETA: 0s - loss: 0.1059 - accuracy: 0.9625
# Epoch 00089: val_loss did not improve from 0.16018
# 80/80 [==============================] - 207s 3s/step - loss: 0.1059 - accuracy: 0.9625 - val_loss: 0.1618 - val_accuracy: 0.8329 - lr: 1.0000e-04
# Epoch 90/175
# 80/80 [==============================] - ETA: 0s - loss: 0.1053 - accuracy: 0.9625
# Epoch 00090: val_loss did not improve from 0.16018
# 80/80 [==============================] - 206s 3s/step - loss: 0.1053 - accuracy: 0.9625 - val_loss: 0.1604 - val_accuracy: 0.8358 - lr: 1.0000e-04
# Epoch 91/175
# 80/80 [==============================] - ETA: 0s - loss: 0.1049 - accuracy: 0.9625
# Epoch 00091: val_loss did not improve from 0.16018
# 80/80 [==============================] - 206s 3s/step - loss: 0.1049 - accuracy: 0.9625 - val_loss: 0.1602 - val_accuracy: 0.8358 - lr: 1.0000e-04
# Epoch 92/175
# 80/80 [==============================] - ETA: 0s - loss: 0.1042 - accuracy: 0.9625
# Epoch 00092: val_loss improved from 0.16018 to 0.15906, saving model to ..\scripts\models_h5\siamese_network2c-t1_20notebook.h5
# 80/80 [==============================] - 206s 3s/step - loss: 0.1042 - accuracy: 0.9625 - val_loss: 0.1591 - val_accuracy: 0.8358 - lr: 1.0000e-04
# Epoch 93/175
# 80/80 [==============================] - ETA: 0s - loss: 0.1037 - accuracy: 0.9625
# Epoch 00093: val_loss did not improve from 0.15906
# 80/80 [==============================] - 207s 3s/step - loss: 0.1037 - accuracy: 0.9625 - val_loss: 0.1599 - val_accuracy: 0.8358 - lr: 1.0000e-04
# Epoch 94/175
# 80/80 [==============================] - ETA: 0s - loss: 0.1033 - accuracy: 0.9625
# Epoch 00094: val_loss did not improve from 0.15906
# 80/80 [==============================] - 206s 3s/step - loss: 0.1033 - accuracy: 0.9625 - val_loss: 0.1604 - val_accuracy: 0.8338 - lr: 1.0000e-04
# Epoch 95/175
# 80/80 [==============================] - ETA: 0s - loss: 0.1032 - accuracy: 0.9625 ETA: 0s - loss: 0.1032
# Epoch 00095: val_loss improved from 0.15906 to 0.15863, saving model to ..\scripts\models_h5\siamese_network2c-t1_20notebook.h5
# 80/80 [==============================] - 206s 3s/step - loss: 0.1032 - accuracy: 0.9625 - val_loss: 0.1586 - val_accuracy: 0.8358 - lr: 1.0000e-04
# Epoch 96/175
# 80/80 [==============================] - ETA: 0s - loss: 0.1024 - accuracy: 0.9625 ETA: 0s - loss: 0.1054
# Epoch 00096: val_loss improved from 0.15863 to 0.15807, saving model to ..\scripts\models_h5\siamese_network2c-t1_20notebook.h5
# 80/80 [==============================] - 205s 3s/step - loss: 0.1024 - accuracy: 0.9625 - val_loss: 0.1581 - val_accuracy: 0.8358 - lr: 1.0000e-04
# Epoch 97/175
# 80/80 [==============================] - ETA: 0s - loss: 0.1020 - accuracy: 0.9625
# Epoch 00097: val_loss did not improve from 0.15807
# 80/80 [==============================] - 206s 3s/step - loss: 0.1020 - accuracy: 0.9625 - val_loss: 0.1583 - val_accuracy: 0.8358 - lr: 1.0000e-04
# Epoch 98/175
# 80/80 [==============================] - ETA: 0s - loss: 0.1018 - accuracy: 0.9625
# Epoch 00098: val_loss did not improve from 0.15807
# 80/80 [==============================] - 206s 3s/step - loss: 0.1018 - accuracy: 0.9625 - val_loss: 0.1582 - val_accuracy: 0.8358 - lr: 1.0000e-04
# Epoch 99/175
# 80/80 [==============================] - ETA: 0s - loss: 0.1011 - accuracy: 0.9625
# Epoch 00099: val_loss improved from 0.15807 to 0.15649, saving model to ..\scripts\models_h5\siamese_network2c-t1_20notebook.h5
# 80/80 [==============================] - 206s 3s/step - loss: 0.1011 - accuracy: 0.9625 - val_loss: 0.1565 - val_accuracy: 0.8363 - lr: 1.0000e-04
# Epoch 100/175
# 80/80 [==============================] - ETA: 0s - loss: 0.1007 - accuracy: 0.9625
# Epoch 00100: val_loss improved from 0.15649 to 0.15611, saving model to ..\scripts\models_h5\siamese_network2c-t1_20notebook.h5
# 80/80 [==============================] - 207s 3s/step - loss: 0.1007 - accuracy: 0.9625 - val_loss: 0.1561 - val_accuracy: 0.8363 - lr: 1.0000e-04
# Epoch 101/175
# 80/80 [==============================] - ETA: 0s - loss: 0.1000 - accuracy: 0.9625
# Epoch 00101: val_loss did not improve from 0.15611
# 80/80 [==============================] - 207s 3s/step - loss: 0.1000 - accuracy: 0.9625 - val_loss: 0.1574 - val_accuracy: 0.8354 - lr: 1.0000e-04
# Epoch 102/175
# 80/80 [==============================] - ETA: 0s - loss: 0.0998 - accuracy: 0.9625
# Epoch 00102: val_loss improved from 0.15611 to 0.15516, saving model to ..\scripts\models_h5\siamese_network2c-t1_20notebook.h5
# 80/80 [==============================] - 206s 3s/step - loss: 0.0998 - accuracy: 0.9625 - val_loss: 0.1552 - val_accuracy: 0.8375 - lr: 1.0000e-04
# Epoch 103/175
# 80/80 [==============================] - ETA: 0s - loss: 0.0992 - accuracy: 0.9625
# Epoch 00103: val_loss did not improve from 0.15516
# 80/80 [==============================] - 207s 3s/step - loss: 0.0992 - accuracy: 0.9625 - val_loss: 0.1554 - val_accuracy: 0.8367 - lr: 1.0000e-04
# Epoch 104/175
# 80/80 [==============================] - ETA: 0s - loss: 0.0986 - accuracy: 0.9625
# Epoch 00104: val_loss improved from 0.15516 to 0.15495, saving model to ..\scripts\models_h5\siamese_network2c-t1_20notebook.h5
# 80/80 [==============================] - 205s 3s/step - loss: 0.0986 - accuracy: 0.9625 - val_loss: 0.1550 - val_accuracy: 0.8363 - lr: 1.0000e-04
# Epoch 105/175
# 80/80 [==============================] - ETA: 0s - loss: 0.0982 - accuracy: 0.9625
# Epoch 00105: val_loss did not improve from 0.15495
# 80/80 [==============================] - 206s 3s/step - loss: 0.0982 - accuracy: 0.9625 - val_loss: 0.1550 - val_accuracy: 0.8363 - lr: 1.0000e-04
# Epoch 106/175
# 80/80 [==============================] - ETA: 0s - loss: 0.0978 - accuracy: 0.9625
# Epoch 00106: val_loss did not improve from 0.15495
# 80/80 [==============================] - 206s 3s/step - loss: 0.0978 - accuracy: 0.9625 - val_loss: 0.1551 - val_accuracy: 0.8363 - lr: 1.0000e-04
# Epoch 107/175
# 80/80 [==============================] - ETA: 0s - loss: 0.0976 - accuracy: 0.9625
# Epoch 00107: val_loss improved from 0.15495 to 0.15435, saving model to ..\scripts\models_h5\siamese_network2c-t1_20notebook.h5
# 80/80 [==============================] - 205s 3s/step - loss: 0.0976 - accuracy: 0.9625 - val_loss: 0.1543 - val_accuracy: 0.8367 - lr: 1.0000e-04
# Epoch 108/175
# 80/80 [==============================] - ETA: 0s - loss: 0.0971 - accuracy: 0.9625
# Epoch 00108: val_loss improved from 0.15435 to 0.15427, saving model to ..\scripts\models_h5\siamese_network2c-t1_20notebook.h5
# 80/80 [==============================] - 207s 3s/step - loss: 0.0971 - accuracy: 0.9625 - val_loss: 0.1543 - val_accuracy: 0.8363 - lr: 1.0000e-04
# Epoch 109/175
# 80/80 [==============================] - ETA: 0s - loss: 0.0964 - accuracy: 0.9625
# Epoch 00109: val_loss improved from 0.15427 to 0.15403, saving model to ..\scripts\models_h5\siamese_network2c-t1_20notebook.h5
# 80/80 [==============================] - 206s 3s/step - loss: 0.0964 - accuracy: 0.9625 - val_loss: 0.1540 - val_accuracy: 0.8367 - lr: 1.0000e-04
# Epoch 110/175
# 80/80 [==============================] - ETA: 0s - loss: 0.0962 - accuracy: 0.9625
# Epoch 00110: val_loss improved from 0.15403 to 0.15302, saving model to ..\scripts\models_h5\siamese_network2c-t1_20notebook.h5
# 80/80 [==============================] - 206s 3s/step - loss: 0.0962 - accuracy: 0.9625 - val_loss: 0.1530 - val_accuracy: 0.8408 - lr: 1.0000e-04
# Epoch 111/175
# 80/80 [==============================] - ETA: 0s - loss: 0.0956 - accuracy: 0.9625
# Epoch 00111: val_loss did not improve from 0.15302
# 80/80 [==============================] - 208s 3s/step - loss: 0.0956 - accuracy: 0.9625 - val_loss: 0.1553 - val_accuracy: 0.8354 - lr: 1.0000e-04
# Epoch 112/175
# 80/80 [==============================] - ETA: 0s - loss: 0.0955 - accuracy: 0.9625
# Epoch 00112: val_loss did not improve from 0.15302
# 80/80 [==============================] - 207s 3s/step - loss: 0.0955 - accuracy: 0.9625 - val_loss: 0.1539 - val_accuracy: 0.8363 - lr: 1.0000e-04
# Epoch 113/175
# 80/80 [==============================] - ETA: 0s - loss: 0.0949 - accuracy: 0.9625
# Epoch 00113: val_loss improved from 0.15302 to 0.15256, saving model to ..\scripts\models_h5\siamese_network2c-t1_20notebook.h5
# 80/80 [==============================] - 206s 3s/step - loss: 0.0949 - accuracy: 0.9625 - val_loss: 0.1526 - val_accuracy: 0.8404 - lr: 1.0000e-04
# Epoch 114/175
# 80/80 [==============================] - ETA: 0s - loss: 0.0948 - accuracy: 0.9625
# Epoch 00114: val_loss improved from 0.15256 to 0.15149, saving model to ..\scripts\models_h5\siamese_network2c-t1_20notebook.h5
# 80/80 [==============================] - 206s 3s/step - loss: 0.0948 - accuracy: 0.9625 - val_loss: 0.1515 - val_accuracy: 0.8429 - lr: 1.0000e-04
# Epoch 115/175
# 80/80 [==============================] - ETA: 0s - loss: 0.0942 - accuracy: 0.9625
# Epoch 00115: val_loss improved from 0.15149 to 0.15120, saving model to ..\scripts\models_h5\siamese_network2c-t1_20notebook.h5
# 80/80 [==============================] - 206s 3s/step - loss: 0.0942 - accuracy: 0.9625 - val_loss: 0.1512 - val_accuracy: 0.8433 - lr: 1.0000e-04
# Epoch 116/175
# 80/80 [==============================] - ETA: 0s - loss: 0.0934 - accuracy: 0.9625
# Epoch 00116: val_loss did not improve from 0.15120
# 80/80 [==============================] - 206s 3s/step - loss: 0.0934 - accuracy: 0.9625 - val_loss: 0.1525 - val_accuracy: 0.8383 - lr: 1.0000e-04
# Epoch 117/175
# 80/80 [==============================] - ETA: 0s - loss: 0.0933 - accuracy: 0.9625
# Epoch 00117: val_loss did not improve from 0.15120
# 80/80 [==============================] - 207s 3s/step - loss: 0.0933 - accuracy: 0.9625 - val_loss: 0.1513 - val_accuracy: 0.8425 - lr: 1.0000e-04
# Epoch 118/175
# 80/80 [==============================] - ETA: 0s - loss: 0.0926 - accuracy: 0.9625
# Epoch 00118: val_loss improved from 0.15120 to 0.15065, saving model to ..\scripts\models_h5\siamese_network2c-t1_20notebook.h5
# 80/80 [==============================] - 206s 3s/step - loss: 0.0926 - accuracy: 0.9625 - val_loss: 0.1506 - val_accuracy: 0.8433 - lr: 1.0000e-04
# Epoch 119/175
# 80/80 [==============================] - ETA: 0s - loss: 0.0923 - accuracy: 0.9625
# Epoch 00119: val_loss improved from 0.15065 to 0.14979, saving model to ..\scripts\models_h5\siamese_network2c-t1_20notebook.h5
# 80/80 [==============================] - 206s 3s/step - loss: 0.0923 - accuracy: 0.9625 - val_loss: 0.1498 - val_accuracy: 0.8438 - lr: 1.0000e-04
# Epoch 120/175
# 80/80 [==============================] - ETA: 0s - loss: 0.0920 - accuracy: 0.9625
# Epoch 00120: val_loss did not improve from 0.14979
# 80/80 [==============================] - 209s 3s/step - loss: 0.0920 - accuracy: 0.9625 - val_loss: 0.1503 - val_accuracy: 0.8433 - lr: 1.0000e-04
# Epoch 121/175
# 80/80 [==============================] - ETA: 0s - loss: 0.0916 - accuracy: 0.9625
# Epoch 00121: val_loss improved from 0.14979 to 0.14933, saving model to ..\scripts\models_h5\siamese_network2c-t1_20notebook.h5
# 80/80 [==============================] - 206s 3s/step - loss: 0.0916 - accuracy: 0.9625 - val_loss: 0.1493 - val_accuracy: 0.8433 - lr: 1.0000e-04
# Epoch 122/175
# 80/80 [==============================] - ETA: 0s - loss: 0.0910 - accuracy: 0.9625
# Epoch 00122: val_loss did not improve from 0.14933
# 80/80 [==============================] - 206s 3s/step - loss: 0.0910 - accuracy: 0.9625 - val_loss: 0.1493 - val_accuracy: 0.8438 - lr: 1.0000e-04
# Epoch 123/175
# 80/80 [==============================] - ETA: 0s - loss: 0.0908 - accuracy: 0.9625
# Epoch 00123: val_loss improved from 0.14933 to 0.14857, saving model to ..\scripts\models_h5\siamese_network2c-t1_20notebook.h5
# 80/80 [==============================] - 206s 3s/step - loss: 0.0908 - accuracy: 0.9625 - val_loss: 0.1486 - val_accuracy: 0.8433 - lr: 1.0000e-04
# Epoch 124/175
# 80/80 [==============================] - ETA: 0s - loss: 0.0901 - accuracy: 0.9625
# Epoch 00124: val_loss improved from 0.14857 to 0.14789, saving model to ..\scripts\models_h5\siamese_network2c-t1_20notebook.h5
# 80/80 [==============================] - 207s 3s/step - loss: 0.0901 - accuracy: 0.9625 - val_loss: 0.1479 - val_accuracy: 0.8450 - lr: 1.0000e-04
# Epoch 125/175
# 80/80 [==============================] - ETA: 0s - loss: 0.0900 - accuracy: 0.9625 ETA: 0s - loss: 0.0930 - accuracy:
# Epoch 00125: val_loss improved from 0.14789 to 0.14785, saving model to ..\scripts\models_h5\siamese_network2c-t1_20notebook.h5
# 80/80 [==============================] - 207s 3s/step - loss: 0.0900 - accuracy: 0.9625 - val_loss: 0.1478 - val_accuracy: 0.8438 - lr: 1.0000e-04
# Epoch 126/175
# 80/80 [==============================] - ETA: 0s - loss: 0.0893 - accuracy: 0.9625
# Epoch 00126: val_loss did not improve from 0.14785
# 80/80 [==============================] - 206s 3s/step - loss: 0.0893 - accuracy: 0.9625 - val_loss: 0.1484 - val_accuracy: 0.8433 - lr: 1.0000e-04
# Epoch 127/175
# 80/80 [==============================] - ETA: 0s - loss: 0.0889 - accuracy: 0.9625
# Epoch 00127: val_loss improved from 0.14785 to 0.14735, saving model to ..\scripts\models_h5\siamese_network2c-t1_20notebook.h5
# 80/80 [==============================] - 206s 3s/step - loss: 0.0889 - accuracy: 0.9625 - val_loss: 0.1473 - val_accuracy: 0.8446 - lr: 1.0000e-04
# Epoch 128/175
# 80/80 [==============================] - ETA: 0s - loss: 0.0885 - accuracy: 0.9625
# Epoch 00128: val_loss improved from 0.14735 to 0.14688, saving model to ..\scripts\models_h5\siamese_network2c-t1_20notebook.h5
# 80/80 [==============================] - 207s 3s/step - loss: 0.0885 - accuracy: 0.9625 - val_loss: 0.1469 - val_accuracy: 0.8458 - lr: 1.0000e-04
# Epoch 129/175
# 80/80 [==============================] - ETA: 0s - loss: 0.0881 - accuracy: 0.9625
# Epoch 00129: val_loss did not improve from 0.14688
# 80/80 [==============================] - 207s 3s/step - loss: 0.0881 - accuracy: 0.9625 - val_loss: 0.1485 - val_accuracy: 0.8438 - lr: 1.0000e-04
# Epoch 130/175
# 80/80 [==============================] - ETA: 0s - loss: 0.0878 - accuracy: 0.9625
# Epoch 00130: val_loss improved from 0.14688 to 0.14642, saving model to ..\scripts\models_h5\siamese_network2c-t1_20notebook.h5
# 80/80 [==============================] - 208s 3s/step - loss: 0.0878 - accuracy: 0.9625 - val_loss: 0.1464 - val_accuracy: 0.8458 - lr: 1.0000e-04
# Epoch 131/175
# 80/80 [==============================] - ETA: 0s - loss: 0.0872 - accuracy: 0.9625
# Epoch 00131: val_loss did not improve from 0.14642
# 80/80 [==============================] - 206s 3s/step - loss: 0.0872 - accuracy: 0.9625 - val_loss: 0.1470 - val_accuracy: 0.8433 - lr: 1.0000e-04
# Epoch 132/175
# 80/80 [==============================] - ETA: 0s - loss: 0.0868 - accuracy: 0.9625
# Epoch 00132: val_loss improved from 0.14642 to 0.14622, saving model to ..\scripts\models_h5\siamese_network2c-t1_20notebook.h5
# 80/80 [==============================] - 205s 3s/step - loss: 0.0868 - accuracy: 0.9625 - val_loss: 0.1462 - val_accuracy: 0.8454 - lr: 1.0000e-04
# Epoch 133/175
# 80/80 [==============================] - ETA: 0s - loss: 0.0865 - accuracy: 0.9625
# Epoch 00133: val_loss did not improve from 0.14622
# 80/80 [==============================] - 208s 3s/step - loss: 0.0865 - accuracy: 0.9625 - val_loss: 0.1465 - val_accuracy: 0.8438 - lr: 1.0000e-04
# Epoch 134/175
# 80/80 [==============================] - ETA: 0s - loss: 0.0863 - accuracy: 0.9625
# Epoch 00134: val_loss improved from 0.14622 to 0.14500, saving model to ..\scripts\models_h5\siamese_network2c-t1_20notebook.h5
# 80/80 [==============================] - 209s 3s/step - loss: 0.0863 - accuracy: 0.9625 - val_loss: 0.1450 - val_accuracy: 0.8471 - lr: 1.0000e-04
# Epoch 135/175
# 80/80 [==============================] - ETA: 0s - loss: 0.0858 - accuracy: 0.9625
# Epoch 00135: val_loss improved from 0.14500 to 0.14480, saving model to ..\scripts\models_h5\siamese_network2c-t1_20notebook.h5
# 80/80 [==============================] - 206s 3s/step - loss: 0.0858 - accuracy: 0.9625 - val_loss: 0.1448 - val_accuracy: 0.8471 - lr: 1.0000e-04
# Epoch 136/175
# 80/80 [==============================] - ETA: 0s - loss: 0.0852 - accuracy: 0.9625
# Epoch 00136: val_loss did not improve from 0.14480
# 80/80 [==============================] - 206s 3s/step - loss: 0.0852 - accuracy: 0.9625 - val_loss: 0.1453 - val_accuracy: 0.8458 - lr: 1.0000e-04
# Epoch 137/175
# 80/80 [==============================] - ETA: 0s - loss: 0.0851 - accuracy: 0.9625
# Epoch 00137: val_loss improved from 0.14480 to 0.14460, saving model to ..\scripts\models_h5\siamese_network2c-t1_20notebook.h5
# 80/80 [==============================] - 207s 3s/step - loss: 0.0851 - accuracy: 0.9625 - val_loss: 0.1446 - val_accuracy: 0.8471 - lr: 1.0000e-04
# Epoch 138/175
# 80/80 [==============================] - ETA: 0s - loss: 0.0844 - accuracy: 0.9625
# Epoch 00138: val_loss did not improve from 0.14460
# 80/80 [==============================] - 207s 3s/step - loss: 0.0844 - accuracy: 0.9625 - val_loss: 0.1455 - val_accuracy: 0.8442 - lr: 1.0000e-04
# Epoch 139/175
# 80/80 [==============================] - ETA: 0s - loss: 0.0844 - accuracy: 0.9625
# Epoch 00139: val_loss did not improve from 0.14460
# 80/80 [==============================] - 206s 3s/step - loss: 0.0844 - accuracy: 0.9625 - val_loss: 0.1450 - val_accuracy: 0.8454 - lr: 1.0000e-04
# Epoch 140/175
# 80/80 [==============================] - ETA: 0s - loss: 0.0838 - accuracy: 0.9625
# Epoch 00140: val_loss improved from 0.14460 to 0.14372, saving model to ..\scripts\models_h5\siamese_network2c-t1_20notebook.h5
# 80/80 [==============================] - 206s 3s/step - loss: 0.0838 - accuracy: 0.9625 - val_loss: 0.1437 - val_accuracy: 0.8471 - lr: 1.0000e-04
# Epoch 141/175
# 80/80 [==============================] - ETA: 0s - loss: 0.0834 - accuracy: 0.9625
# Epoch 00141: val_loss did not improve from 0.14372
# 80/80 [==============================] - 206s 3s/step - loss: 0.0834 - accuracy: 0.9625 - val_loss: 0.1439 - val_accuracy: 0.8471 - lr: 1.0000e-04
# Epoch 142/175
# 80/80 [==============================] - ETA: 0s - loss: 0.0831 - accuracy: 0.9625
# Epoch 00142: val_loss did not improve from 0.14372
# 80/80 [==============================] - 207s 3s/step - loss: 0.0831 - accuracy: 0.9625 - val_loss: 0.1455 - val_accuracy: 0.8433 - lr: 1.0000e-04
# Epoch 143/175
# 80/80 [==============================] - ETA: 0s - loss: 0.0833 - accuracy: 0.9625
# Epoch 00143: val_loss did not improve from 0.14372
# 80/80 [==============================] - 209s 3s/step - loss: 0.0833 - accuracy: 0.9625 - val_loss: 0.1457 - val_accuracy: 0.8429 - lr: 1.0000e-04
# Epoch 144/175
# 80/80 [==============================] - ETA: 0s - loss: 0.0823 - accuracy: 0.9625
# Epoch 00144: val_loss improved from 0.14372 to 0.14348, saving model to ..\scripts\models_h5\siamese_network2c-t1_20notebook.h5
# 80/80 [==============================] - 206s 3s/step - loss: 0.0823 - accuracy: 0.9625 - val_loss: 0.1435 - val_accuracy: 0.8471 - lr: 1.0000e-04
# Epoch 145/175
# 80/80 [==============================] - ETA: 0s - loss: 0.0825 - accuracy: 0.9625
# Epoch 00145: val_loss improved from 0.14348 to 0.14321, saving model to ..\scripts\models_h5\siamese_network2c-t1_20notebook.h5
# 80/80 [==============================] - 214s 3s/step - loss: 0.0825 - accuracy: 0.9625 - val_loss: 0.1432 - val_accuracy: 0.8471 - lr: 1.0000e-04
# Epoch 146/175
# 80/80 [==============================] - ETA: 0s - loss: 0.0815 - accuracy: 0.9625
# Epoch 00146: val_loss did not improve from 0.14321
# 80/80 [==============================] - 209s 3s/step - loss: 0.0815 - accuracy: 0.9625 - val_loss: 0.1440 - val_accuracy: 0.8454 - lr: 1.0000e-04
# Epoch 147/175
# 80/80 [==============================] - ETA: 0s - loss: 0.0812 - accuracy: 0.9625
# Epoch 00147: val_loss improved from 0.14321 to 0.14302, saving model to ..\scripts\models_h5\siamese_network2c-t1_20notebook.h5
# 80/80 [==============================] - 206s 3s/step - loss: 0.0812 - accuracy: 0.9625 - val_loss: 0.1430 - val_accuracy: 0.8471 - lr: 1.0000e-04
# Epoch 148/175
# 80/80 [==============================] - ETA: 0s - loss: 0.0810 - accuracy: 0.9625 ETA
# Epoch 00148: val_loss improved from 0.14302 to 0.14144, saving model to ..\scripts\models_h5\siamese_network2c-t1_20notebook.h5
# 80/80 [==============================] - 206s 3s/step - loss: 0.0810 - accuracy: 0.9625 - val_loss: 0.1414 - val_accuracy: 0.8492 - lr: 1.0000e-04
# Epoch 149/175
# 80/80 [==============================] - ETA: 0s - loss: 0.0803 - accuracy: 0.9625
# Epoch 00149: val_loss improved from 0.14144 to 0.14133, saving model to ..\scripts\models_h5\siamese_network2c-t1_20notebook.h5
# 80/80 [==============================] - 206s 3s/step - loss: 0.0803 - accuracy: 0.9625 - val_loss: 0.1413 - val_accuracy: 0.8487 - lr: 1.0000e-04
# Epoch 150/175
# 80/80 [==============================] - ETA: 0s - loss: 0.0802 - accuracy: 0.9625
# Epoch 00150: val_loss did not improve from 0.14133
# 80/80 [==============================] - 206s 3s/step - loss: 0.0802 - accuracy: 0.9625 - val_loss: 0.1420 - val_accuracy: 0.8475 - lr: 1.0000e-04
# Epoch 151/175
# 80/80 [==============================] - ETA: 0s - loss: 0.0797 - accuracy: 0.9625
# Epoch 00151: val_loss improved from 0.14133 to 0.13989, saving model to ..\scripts\models_h5\siamese_network2c-t1_20notebook.h5
# 80/80 [==============================] - 207s 3s/step - loss: 0.0797 - accuracy: 0.9625 - val_loss: 0.1399 - val_accuracy: 0.8508 - lr: 1.0000e-04
# Epoch 152/175
# 80/80 [==============================] - ETA: 0s - loss: 0.0797 - accuracy: 0.9625 E
# Epoch 00152: val_loss did not improve from 0.13989
# 80/80 [==============================] - 207s 3s/step - loss: 0.0797 - accuracy: 0.9625 - val_loss: 0.1401 - val_accuracy: 0.8496 - lr: 1.0000e-04
# Epoch 153/175
# 80/80 [==============================] - ETA: 0s - loss: 0.0792 - accuracy: 0.9625
# Epoch 00153: val_loss improved from 0.13989 to 0.13973, saving model to ..\scripts\models_h5\siamese_network2c-t1_20notebook.h5
# 80/80 [==============================] - 206s 3s/step - loss: 0.0792 - accuracy: 0.9625 - val_loss: 0.1397 - val_accuracy: 0.8496 - lr: 1.0000e-04
# Epoch 154/175
# 80/80 [==============================] - ETA: 0s - loss: 0.0789 - accuracy: 0.9625
# Epoch 00154: val_loss did not improve from 0.13973
# 80/80 [==============================] - 207s 3s/step - loss: 0.0789 - accuracy: 0.9625 - val_loss: 0.1410 - val_accuracy: 0.8475 - lr: 1.0000e-04
# Epoch 155/175
# 80/80 [==============================] - ETA: 0s - loss: 0.0786 - accuracy: 0.9625
# Epoch 00155: val_loss did not improve from 0.13973
# 80/80 [==============================] - 207s 3s/step - loss: 0.0786 - accuracy: 0.9625 - val_loss: 0.1407 - val_accuracy: 0.8475 - lr: 1.0000e-04
# Epoch 156/175
# 80/80 [==============================] - ETA: 0s - loss: 0.0777 - accuracy: 0.9625
# Epoch 00156: val_loss improved from 0.13973 to 0.13911, saving model to ..\scripts\models_h5\siamese_network2c-t1_20notebook.h5
# 80/80 [==============================] - 208s 3s/step - loss: 0.0777 - accuracy: 0.9625 - val_loss: 0.1391 - val_accuracy: 0.8496 - lr: 1.0000e-04
# Epoch 157/175
# 80/80 [==============================] - ETA: 0s - loss: 0.0778 - accuracy: 0.9625
# Epoch 00157: val_loss did not improve from 0.13911
# 80/80 [==============================] - 206s 3s/step - loss: 0.0778 - accuracy: 0.9625 - val_loss: 0.1392 - val_accuracy: 0.8496 - lr: 1.0000e-04
# Epoch 158/175
# 80/80 [==============================] - ETA: 0s - loss: 0.0773 - accuracy: 0.9625
# Epoch 00158: val_loss improved from 0.13911 to 0.13880, saving model to ..\scripts\models_h5\siamese_network2c-t1_20notebook.h5
# 80/80 [==============================] - 207s 3s/step - loss: 0.0773 - accuracy: 0.9625 - val_loss: 0.1388 - val_accuracy: 0.8496 - lr: 1.0000e-04
# Epoch 159/175
# 80/80 [==============================] - ETA: 0s - loss: 0.0768 - accuracy: 0.9625
# Epoch 00159: val_loss did not improve from 0.13880
# 80/80 [==============================] - 207s 3s/step - loss: 0.0768 - accuracy: 0.9625 - val_loss: 0.1401 - val_accuracy: 0.8475 - lr: 1.0000e-04
# Epoch 160/175
# 80/80 [==============================] - ETA: 0s - loss: 0.0765 - accuracy: 0.9625
# Epoch 00160: val_loss improved from 0.13880 to 0.13877, saving model to ..\scripts\models_h5\siamese_network2c-t1_20notebook.h5
# 80/80 [==============================] - 208s 3s/step - loss: 0.0765 - accuracy: 0.9625 - val_loss: 0.1388 - val_accuracy: 0.8487 - lr: 1.0000e-04
# Epoch 161/175
# 80/80 [==============================] - ETA: 0s - loss: 0.0761 - accuracy: 0.9625 ETA: 0s - loss: 0.0706 - accu
# Epoch 00161: val_loss improved from 0.13877 to 0.13847, saving model to ..\scripts\models_h5\siamese_network2c-t1_20notebook.h5
# 80/80 [==============================] - 208s 3s/step - loss: 0.0761 - accuracy: 0.9625 - val_loss: 0.1385 - val_accuracy: 0.8496 - lr: 1.0000e-04
# Epoch 162/175
# 80/80 [==============================] - ETA: 0s - loss: 0.0758 - accuracy: 0.9625
# Epoch 00162: val_loss did not improve from 0.13847
# 80/80 [==============================] - 207s 3s/step - loss: 0.0758 - accuracy: 0.9625 - val_loss: 0.1395 - val_accuracy: 0.8471 - lr: 1.0000e-04
# Epoch 163/175
# 80/80 [==============================] - ETA: 0s - loss: 0.0757 - accuracy: 0.9625
# Epoch 00163: val_loss improved from 0.13847 to 0.13778, saving model to ..\scripts\models_h5\siamese_network2c-t1_20notebook.h5
# 80/80 [==============================] - 208s 3s/step - loss: 0.0757 - accuracy: 0.9625 - val_loss: 0.1378 - val_accuracy: 0.8500 - lr: 1.0000e-04
# Epoch 164/175
# 80/80 [==============================] - ETA: 0s - loss: 0.0753 - accuracy: 0.9625
# Epoch 00164: val_loss improved from 0.13778 to 0.13714, saving model to ..\scripts\models_h5\siamese_network2c-t1_20notebook.h5
# 80/80 [==============================] - 207s 3s/step - loss: 0.0753 - accuracy: 0.9625 - val_loss: 0.1371 - val_accuracy: 0.8521 - lr: 1.0000e-04
# Epoch 165/175
# 80/80 [==============================] - ETA: 0s - loss: 0.0751 - accuracy: 0.9625
# Epoch 00165: val_loss improved from 0.13714 to 0.13693, saving model to ..\scripts\models_h5\siamese_network2c-t1_20notebook.h5
# 80/80 [==============================] - 207s 3s/step - loss: 0.0751 - accuracy: 0.9625 - val_loss: 0.1369 - val_accuracy: 0.8521 - lr: 1.0000e-04
# Epoch 166/175
# 80/80 [==============================] - ETA: 0s - loss: 0.0744 - accuracy: 0.9625
# Epoch 00166: val_loss did not improve from 0.13693
# 80/80 [==============================] - 206s 3s/step - loss: 0.0744 - accuracy: 0.9625 - val_loss: 0.1370 - val_accuracy: 0.8512 - lr: 1.0000e-04
# Epoch 167/175
# 80/80 [==============================] - ETA: 0s - loss: 0.0743 - accuracy: 0.9625
# Epoch 00167: val_loss improved from 0.13693 to 0.13623, saving model to ..\scripts\models_h5\siamese_network2c-t1_20notebook.h5
# 80/80 [==============================] - 209s 3s/step - loss: 0.0743 - accuracy: 0.9625 - val_loss: 0.1362 - val_accuracy: 0.8537 - lr: 1.0000e-04
# Epoch 168/175
# 80/80 [==============================] - ETA: 0s - loss: 0.0742 - accuracy: 0.9625
# Epoch 00168: val_loss improved from 0.13623 to 0.13608, saving model to ..\scripts\models_h5\siamese_network2c-t1_20notebook.h5
# 80/80 [==============================] - 207s 3s/step - loss: 0.0742 - accuracy: 0.9625 - val_loss: 0.1361 - val_accuracy: 0.8537 - lr: 1.0000e-04
# Epoch 169/175
# 80/80 [==============================] - ETA: 0s - loss: 0.0735 - accuracy: 0.9625 ETA: 0s - loss: 0.0743 - accuracy: 0.96
# Epoch 00169: val_loss did not improve from 0.13608
# 80/80 [==============================] - 207s 3s/step - loss: 0.0735 - accuracy: 0.9625 - val_loss: 0.1366 - val_accuracy: 0.8508 - lr: 1.0000e-04
# Epoch 170/175
# 80/80 [==============================] - ETA: 0s - loss: 0.0734 - accuracy: 0.9625
# Epoch 00170: val_loss did not improve from 0.13608
# 80/80 [==============================] - 206s 3s/step - loss: 0.0734 - accuracy: 0.9625 - val_loss: 0.1369 - val_accuracy: 0.8496 - lr: 1.0000e-04
# Epoch 171/175
# 80/80 [==============================] - ETA: 0s - loss: 0.0727 - accuracy: 0.9625
# Epoch 00171: val_loss improved from 0.13608 to 0.13502, saving model to ..\scripts\models_h5\siamese_network2c-t1_20notebook.h5
# 80/80 [==============================] - 206s 3s/step - loss: 0.0727 - accuracy: 0.9625 - val_loss: 0.1350 - val_accuracy: 0.8537 - lr: 1.0000e-04
# Epoch 172/175
# 80/80 [==============================] - ETA: 0s - loss: 0.0728 - accuracy: 0.9625 ETA: 0s - loss: 0.0735 - accuracy
# Epoch 00172: val_loss did not improve from 0.13502
# 80/80 [==============================] - 207s 3s/step - loss: 0.0728 - accuracy: 0.9625 - val_loss: 0.1355 - val_accuracy: 0.8542 - lr: 1.0000e-04
# Epoch 173/175
# 80/80 [==============================] - ETA: 0s - loss: 0.0724 - accuracy: 0.9625
# Epoch 00173: val_loss did not improve from 0.13502
# 80/80 [==============================] - 206s 3s/step - loss: 0.0724 - accuracy: 0.9625 - val_loss: 0.1355 - val_accuracy: 0.8525 - lr: 1.0000e-04
# Epoch 174/175
# 80/80 [==============================] - ETA: 0s - loss: 0.0720 - accuracy: 0.9625
# Epoch 00174: val_loss did not improve from 0.13502
# 80/80 [==============================] - 207s 3s/step - loss: 0.0720 - accuracy: 0.9625 - val_loss: 0.1354 - val_accuracy: 0.8521 - lr: 1.0000e-04
# Epoch 175/175
# 80/80 [==============================] - ETA: 0s - loss: 0.0717 - accuracy: 0.9625
# Epoch 00175: val_loss did not improve from 0.13502
# 80/80 [==============================] - 206s 3s/step - loss: 0.0717 - accuracy: 0.9625 - val_loss: 0.1359 - val_accuracy: 0.8504 - lr: 1.0000e-04

# %%
results = siamese.evaluate([x_test_1, x_test_2], labels_test)
print("test loss, test acc:", results)
# Out:
# 75/75 [==============================] - 160s 2s/step - loss: 0.0769 - accuracy: 0.9592
# test loss, test acc: [0.07690799236297607, 0.9591666460037231]

# %%
Y_pred = siamese.predict([x_test_1, x_test_2]).squeeze()
# 返回的是TRUE或FALSE,没有标签数据怎么知道他被分到哪儿个类中？
y_pred = Y_pred > 0.5
# x1,和x2是否匹配：匹配1，不匹配0
y_test = labels_test
print("\nEvaluate on validation data")
Accuracy=accuracy_score(y_test, y_pred)
Precision=precision_score(y_test, y_pred, average='weighted')
Recall=recall_score(y_test, y_pred, average='weighted')
ROC_AUC=roc_auc_score(y_test, y_pred, average='weighted')
F1=f1_score(y_test, y_pred, average='weighted')
print("Accuracy:", Accuracy)
print("Precision:", Precision)
print("Recall:", Recall)
print("ROC AUC:", ROC_AUC)
print("F1:",F1 )
# Out:
# Evaluate on validation data
# Accuracy: 0.9591666666666666
# Precision: 0.9600983658575282
# Recall: 0.9591666666666666
# ROC AUC: 0.9591666666666666
# F1: 0.9591459843212292

# %%
y_pred = [1 if i else 0 for i in y_pred]
pred_labels = []

for i in range(0, len(y_pred)):
    if y_pred[i] == 1:
        pred_labels += [source_labels_test[i]]
    else:
        if source_labels_test[i] == 1:
            pred_labels += [0.0]
        else:
            pred_labels += [1.0]
a = x_test_1.tolist()
df = pd.DataFrame({"image": a, "label_{}".format(teacher_id): pred_labels})
if not os.path.exists(pre_results_path):
    os.makedirs(pre_results_path)
df.to_excel(os.path.join(pre_results_path,"{}_{}_{}.xlsx".format(epochs,teacher_id,shot)),index=False)

# %%
cm = confusion_matrix(y_test, y_pred)
cm_display = ConfusionMatrixDisplay(cm).plot()
plt.show()
tn, fp, fn, tp = cm.ravel()
specificity = tn / (tn + fp)
print("Specificity:", specificity)
data_list=[{"Accuracy":Accuracy,"Precision":Precision,"Recall":Recall,"ROC_AUC":ROC_AUC,"tn":tn,"fp":fp,"fn":fn,"tp":tp,"specificity":specificity}]
df=pd.DataFrame(data_list)

filepath=os.path.join(base_dir,r"acc_{}_{}".format(all_teachers,shot))
if not os.path.exists(filepath):
    os.mkdir(filepath)
df.to_excel(os.path.join(filepath,"{}_{}.xlsx".format(teacher_id,shot)),index=False)
tf.keras.backend.clear_session()
# Out:
# Specificity: 0.9816666666666667
